# %% [markdown]
# # Autonomous Driving - Car Detection
#
# Welcome to the programming assignment! In this notebook, you'll implement object detection using the very powerful YOLO model. Many of the ideas in this notebook are described in the two YOLO papers: [Redmon et al., 2016](https://arxiv.org/abs/1506.02640) and [Redmon and Farhadi, 2016](https://arxiv.org/abs/1612.08242).
#
# **By the end of this assignment, you'll be able to**:
#
# - Detect objects in a car detection dataset
# - Implement non-max suppression to increase accuracy
# - Implement intersection over union
# - Handle bounding boxes, a type of image annotation popular in deep learning
#
# ## Important Note on Submission to the AutoGrader
#
# Before submitting your assignment to the AutoGrader, please make sure you are not doing the following:
#
# 1. You have not added any _extra_ `print` statement(s) in the assignment.
# 2. You have not added any _extra_ code cell(s) in the assignment.
# 3. You have not changed any of the function parameters.
# 4. You are not using any global variables inside your graded exercises. Unless specifically instructed to do so, please refrain from it and use the local variables instead.
# 5. You are not changing the assignment code where it is not required, like creating _extra_ variables.
#
# If you do any of the following, you will get something like, `Grader Error: Grader feedback not found` (or similarly unexpected) error upon submitting your assignment. Before asking for help/debugging the errors in your assignment, check for these first. If this is the case, and you don't remember the changes you have made, you can get a fresh copy of the assignment by following these [instructions](https://www.coursera.org/learn/convolutional-neural-networks/supplement/DS4yP/h-ow-to-refresh-your-workspace).

# %% [markdown]
# ## Table of Contents
#
# - [Packages](#0)
# - [1 - Problem Statement](#1)
# - [2 - YOLO](#2)
#     - [2.1 - Model Details](#2-1)
#     - [2.2 - Filtering with a Threshold on Class Scores](#2-2)
#         - [Exercise 1 - yolo_filter_boxes](#ex-1)
#     - [2.3 - Non-max Suppression](#2-3)
#         - [Exercise 2 - iou](#ex-2)
#     - [2.4 - YOLO Non-max Suppression](#2-4)
#         - [Exercise 3 - yolo_non_max_suppression](#ex-3)
#     - [2.5 - Wrapping Up the Filtering](#2-5)
#         - [Exercise 4 - yolo_eval](#ex-4)
# - [3 - Test YOLO Pre-trained Model on Images](#3)
#     - [3.1 - Defining Classes, Anchors and Image Shape](#3-1)
#     - [3.2 - Loading a Pre-trained Model](#3-2)
#     - [3.3 - Convert Output of the Model to Usable Bounding Box Tensors](#3-3)
#     - [3.4 - Filtering Boxes](#3-4)
#     - [3.5 - Run the YOLO on an Image](#3-5)
# - [4 - Summary for YOLO](#4)
# - [5 - References](#5)

# %% [markdown]
# <a name='0'></a>
# ## Packages
#
# Run the following cell to load the packages and dependencies that will come in handy as you build the object detector!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys

BASE_URL = '/content/drive/MyDrive/Colab Notebooks/DPL/Lab/Lab1/Lab_3_full_v1'

sys.path.append(BASE_URL)

print(BASE_URL)
# Out:
# /content/drive/MyDrive/Colab Notebooks/DPL/Lab/Lab1/Lab_3_full_v1

# %%
import argparse
import os
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import scipy.io
import scipy.misc
import numpy as np
import pandas as pd
import PIL
from PIL import ImageFont, ImageDraw, Image
import tensorflow as tf
from tensorflow.python.framework.ops import EagerTensor

from tensorflow.keras.models import load_model

from yad2k.yad2k.models.keras_yolo import yolo_head
from yad2k.yad2k.utils.draw_boxes import draw_boxes
from yad2k.yad2k.utils.draw_boxes import get_colors_for_classes
from yad2k.yad2k.utils.utils import scale_boxes, read_classes, read_anchors, preprocess_image

# %matplotlib inline
# Out:
# /tmp/ipython-input-498028061.py:6: DeprecationWarning: scipy.misc is deprecated and will be removed in 2.0.0
#   import scipy.misc

# %% [markdown]
# <a name='1'></a>
# ## 1 - Problem Statement
#
# You are working on a self-driving car. Go you! As a critical component of this project, you'd like to first build a car detection system. To collect data, you've mounted a camera to the hood (meaning the front) of the car, which takes pictures of the road ahead every few seconds as you drive around.
#
# <center>
# <video width="400" height="200" src="nb_images/road_video_compressed2.mp4" type="video/mp4" controls>
# </video>
# </center>
#
# <caption><center> Pictures taken from a car-mounted camera while driving around Silicon Valley. <br> Dataset provided by <a href="https://www.drive.ai/">drive.ai</a>.
# </center></caption>
#
# You've gathered all these images into a folder and labelled them by drawing bounding boxes around every car you found. Here's an example of what your bounding boxes look like:
#
# <img src="nb_images/box_label.png" style="width:500px;height:250;">
# <caption><center> <u><b>Figure 1</u></b>: Definition of a box<br> </center></caption>
#
# If there are 80 classes you want the object detector to recognize, you can represent the class label $c$ either as an integer from 1 to 80, or as an 80-dimensional vector (with 80 numbers) one component of which is 1, and the rest of which are 0. The video lectures used the latter representation; in this notebook, you'll use both representations, depending on which is more convenient for a particular step.
#
# In this exercise, you'll discover how YOLO ("You Only Look Once") performs object detection, and then apply it to car detection. Because the YOLO model is very computationally expensive to train, the pre-trained weights are already loaded for you to use.

# %% [markdown]
# <a name='2'></a>
# ## 2 - YOLO

# %% [markdown]
# "You Only Look Once" (YOLO) is a popular algorithm because it achieves high accuracy while also being able to run in real time. This algorithm "only looks once" at the image in the sense that it requires only one forward propagation pass through the network to make predictions. After non-max suppression, it then outputs recognized objects together with the bounding boxes.
#
# <a name='2-1'></a>
# ### 2.1 - Model Details
#
# #### Inputs and outputs
# - The **input** is a batch of images, and each image has the shape (608, 608, 3)
# - The **output** is a list of bounding boxes along with the recognized classes. Each bounding box is represented by 6 numbers $(p_c, b_x, b_y, b_h, b_w, c)$ as explained above. If you expand $c$ into an 80-dimensional vector, each bounding box is then represented by 85 numbers.
#
# #### Anchor Boxes
# * Anchor boxes are chosen by exploring the training data to choose reasonable height/width ratios that represent the different classes.  For this assignment, 5 anchor boxes were chosen for you (to cover the 80 classes), and stored in the file './model_data/yolo_anchors.txt'
# * The dimension of the encoding tensor of the second to last dimension based on the anchor boxes is $(m, n_H,n_W,anchors,classes)$.
# * The YOLO architecture is: IMAGE (m, 608, 608, 3) -> DEEP CNN -> ENCODING (m, 19, 19, 5, 85).
#
# #### Encoding
# Let's look in greater detail at what this encoding represents.
#
# <img src="nb_images/architecture.png" style="width:700px;height:400;">
# <caption><center> <u><b> Figure 2 </u></b>: Encoding architecture for YOLO<br> </center></caption>
#
# If the center/midpoint of an object falls into a grid cell, that grid cell is responsible for detecting that object.

# %% [markdown]
# Since you're using 5 anchor boxes, each of the 19 x19 cells thus encodes information about 5 boxes. Anchor boxes are defined only by their width and height.
#
# For simplicity, you'll flatten the last two dimensions of the shape (19, 19, 5, 85) encoding, so the output of the Deep CNN is (19, 19, 425).
#
# <img src="nb_images/flatten.png" style="width:700px;height:400;">
# <caption><center> <u><b> Figure 3 </u></b>: Flattening the last two last dimensions<br> </center></caption>

# %% [markdown]
# #### Class score
#
# Now, for each box (of each cell) you'll compute the following element-wise product and extract a probability that the box contains a certain class.
# The class score is $score_{c,i} = p_{c} \times c_{i}$: the probability that there is an object $p_{c}$ times the probability that the object is a certain class $c_{i}$.
#
# <img src="nb_images/probability_extraction.png" style="width:700px;height:400;">
# <caption><center> <u><b>Figure 4</u></b>: Find the class detected by each box<br> </center></caption>
#
# ##### Example of figure 4
# * In figure 4, let's say for box 1 (cell 1), the probability that an object exists is $p_{1}=0.60$.  So there's a 60% chance that an object exists in box 1 (cell 1).
# * The probability that the object is the class "category 3 (a car)" is $c_{3}=0.73$.
# * The score for box 1 and for category "3" is $score_{1,3}=0.60 \times 0.73 = 0.44$.
# * Let's say you calculate the score for all 80 classes in box 1, and find that the score for the car class (class 3) is the maximum.  So you'll assign the score 0.44 and class "3" to this box "1".
#
# #### Visualizing classes
# Here's one way to visualize what YOLO is predicting on an image:
#
# - For each of the 19x19 grid cells, find the maximum of the probability scores (taking a max across the 80 classes, one maximum for each of the 5 anchor boxes).
# - Color that grid cell according to what object that grid cell considers the most likely.
#
# Doing this results in this picture:
#
# <img src="nb_images/proba_map.png" style="width:300px;height:300;">
# <caption><center> <u><b>Figure 5</u></b>: Each one of the 19x19 grid cells is colored according to which class has the largest predicted probability in that cell.<br> </center></caption>
#
# Note that this visualization isn't a core part of the YOLO algorithm itself for making predictions; it's just a nice way of visualizing an intermediate result of the algorithm.

# %% [markdown]
# #### Visualizing bounding boxes
# Another way to visualize YOLO's output is to plot the bounding boxes that it outputs. Doing that results in a visualization like this:
#
# <img src="nb_images/anchor_map.png" style="width:200px;height:200;">
# <caption><center> <u><b>Figure 6</u></b>: Each cell gives you 5 boxes. In total, the model predicts: 19x19x5 = 1805 boxes just by looking once at the image (one forward pass through the network)! Different colors denote different classes. <br> </center></caption>
#
# #### Non-Max suppression
# In the figure above, the only boxes plotted are ones for which the model had assigned a high probability, but this is still too many boxes. You'd like to reduce the algorithm's output to a much smaller number of detected objects.
#
# To do so, you'll use **non-max suppression**. Specifically, you'll carry out these steps:
# - Get rid of boxes with a low score. Meaning, the box is not very confident about detecting a class, either due to the low probability of any object, or low probability of this particular class.
# - Select only one box when several boxes overlap with each other and detect the same object.

# %% [markdown]
# <a name='2-2'></a>
# ### 2.2 - Filtering with a Threshold on Class Scores
#
# You're going to first apply a filter by thresholding, meaning you'll get rid of any box for which the class "score" is less than a chosen threshold.
#
# The model gives you a total of 19x19x5x85 numbers, with each box described by 85 numbers. It's convenient to rearrange the (19,19,5,85) (or (19,19,425)) dimensional tensor into the following variables:
# - `box_confidence`: tensor of shape $(19, 19, 5, 1)$ containing $p_c$ (confidence probability that there's some object) for each of the 5 boxes predicted in each of the 19x19 cells.
# - `boxes`: tensor of shape $(19, 19, 5, 4)$ containing the midpoint and dimensions $(b_x, b_y, b_h, b_w)$ for each of the 5 boxes in each cell.
# - `box_class_probs`: tensor of shape $(19, 19, 5, 80)$ containing the "class probabilities" $(c_1, c_2, ... c_{80})$ for each of the 80 classes for each of the 5 boxes per cell.
#
# <a name='ex-1'></a>
# ### Exercise 1 - yolo_filter_boxes
#
# Implement `yolo_filter_boxes()`.
# 1. Compute box scores by doing the elementwise product as described in Figure 4 ($p \times c$).
# The following code may help you choose the right operator:
# ```python
# a = np.random.randn(19, 19, 5, 1)
# b = np.random.randn(19, 19, 5, 80)
# c = a * b # shape of c will be (19, 19, 5, 80)
# ```
# This is an example of **broadcasting** (multiplying vectors of different sizes).
#
# 2. For each box, find:
#     - the index of the class with the maximum box score
#     - the corresponding box score
#
#     **Useful References**
#         * [tf.math.argmax](https://www.tensorflow.org/api_docs/python/tf/math/argmax)
#         * [tf.math.reduce_max](https://www.tensorflow.org/api_docs/python/tf/math/reduce_max)
#
#     **Helpful Hints**
#         * For the `axis` parameter of `argmax` and `reduce_max`, if you want to select the **last** axis, one way to do so is to set `axis=-1`.  This is similar to Python array indexing, where you can select the last position of an array using `arrayname[-1]`.
#         * Applying `reduce_max` normally collapses the axis for which the maximum is applied.  `keepdims=False` is the default option, and allows that dimension to be removed.  You don't need to keep the last dimension after applying the maximum here.
#
#
# 3. Create a mask by using a threshold. As a reminder: `([0.9, 0.3, 0.4, 0.5, 0.1] < 0.4)` returns: `[False, True, False, False, True]`. The mask should be `True` for the boxes you want to keep.
#
# 4. Use TensorFlow to apply the mask to `box_class_scores`, `boxes` and `box_classes` to filter out the boxes you don't want. You should be left with just the subset of boxes you want to keep.
#
#     **One more useful reference**:
#     * [tf.boolean mask](https://www.tensorflow.org/api_docs/python/tf/boolean_mask)
#
#    **And one more helpful hint**: :)
#     * For the `tf.boolean_mask`, you can keep the default `axis=None`.

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: yolo_filter_boxes

def yolo_filter_boxes(boxes, box_confidence, box_class_probs, threshold = .6):
    """Filters YOLO boxes by thresholding on object and class confidence.

    Arguments:
        boxes -- tensor of shape (19, 19, 5, 4)
        box_confidence -- tensor of shape (19, 19, 5, 1)
        box_class_probs -- tensor of shape (19, 19, 5, 80)
        threshold -- real value, if [ highest class probability score < threshold],
                     then get rid of the corresponding box

    Returns:
        scores -- tensor of shape (None,), containing the class probability score for selected boxes
        boxes -- tensor of shape (None, 4), containing (b_x, b_y, b_h, b_w) coordinates of selected boxes
        classes -- tensor of shape (None,), containing the index of the class detected by the selected boxes

    Note: "None" is here because you don't know the exact number of selected boxes, as it depends on the threshold.
    For example, the actual output size of scores would be (10,) if there are 10 boxes.
    """

    ### START CODE HERE
    # Step 1: Compute box scores
    ##(≈ 1 line)
    box_scores = box_confidence * box_class_probs

    # Step 2: Find the box_classes using the max box_scores, keep track of the corresponding score
    ##(≈ 2 lines)
    # IMPORTANT: set axis to -1
    box_classes = tf.math.argmax(box_scores, axis=-1)
    box_class_scores = tf.math.reduce_max(box_scores, axis=-1)

    # Step 3: Create a filtering mask based on "box_class_scores" by using "threshold". The mask should have the
    # same dimension as box_class_scores, and be True for the boxes you want to keep (with probability >= threshold)
    ## (≈ 1 line)
    filtering_mask = box_class_scores >= threshold

    # Step 4: Apply the mask to box_class_scores, boxes and box_classes
    ## (≈ 3 lines)
    scores = tf.boolean_mask(box_class_scores, filtering_mask)
    boxes = tf.boolean_mask(boxes, filtering_mask)
    classes = tf.boolean_mask(box_classes, filtering_mask)
    ### END CODE HERE

    return scores, boxes, classes

# %%
# BEGIN UNIT TEST
tf.random.set_seed(10)
box_confidence = tf.random.normal([19, 19, 5, 1], mean=1, stddev=4, seed = 1)
boxes = tf.random.normal([19, 19, 5, 4], mean=1, stddev=4, seed = 1)
box_class_probs = tf.random.normal([19, 19, 5, 80], mean=1, stddev=4, seed = 1)
scores, boxes, classes = yolo_filter_boxes(boxes, box_confidence, box_class_probs, threshold = 0.5)
print("scores[2] = " + str(scores[2].numpy()))
print("boxes[2] = " + str(boxes[2].numpy()))
print("classes[2] = " + str(classes[2].numpy()))
print("scores.shape = " + str(scores.shape))
print("boxes.shape = " + str(boxes.shape))
print("classes.shape = " + str(classes.shape))

assert type(scores) == EagerTensor, "Use tensorflow functions"
assert type(boxes) == EagerTensor, "Use tensorflow functions"
assert type(classes) == EagerTensor, "Use tensorflow functions"

assert scores.shape == (1789,), "Wrong shape in scores"
assert boxes.shape == (1789, 4), "Wrong shape in boxes"
assert classes.shape == (1789,), "Wrong shape in classes"

assert np.isclose(scores[2].numpy(), 9.270486), "Values are wrong on scores"
assert np.allclose(boxes[2].numpy(), [4.6399336, 3.2303846, 4.431282, -2.202031]), "Values are wrong on boxes"
assert classes[2].numpy() == 8, "Values are wrong on classes"

print("\033[92m All tests passed!")
# END UNIT TEST
# Out:
# scores[2] = 9.270486
# boxes[2] = [ 4.639934   3.2303846  4.431282  -2.2020311]
# classes[2] = 8
# scores.shape = (1789,)
# boxes.shape = (1789, 4)
# classes.shape = (1789,)
#  All tests passed!

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#             <b>scores[2]</b>
#         </td>
#         <td>
#            9.270486
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>boxes[2]</b>
#         </td>
#         <td>
#            [ 4.6399336  3.2303846  4.431282  -2.202031 ]
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>classes[2]</b>
#         </td>
#         <td>
#            8
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <b>scores.shape</b>
#         </td>
#         <td>
#            (1789,)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>boxes.shape</b>
#         </td>
#         <td>
#            (1789, 4)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>classes.shape</b>
#         </td>
#         <td>
#            (1789,)
#         </td>
#     </tr>
#
# </table>

# %% [markdown]
# **Note** In the test for `yolo_filter_boxes`, you're using random numbers to test the function.  In real data, the `box_class_probs` would contain non-zero values between 0 and 1 for the probabilities.  The box coordinates in `boxes` would also be chosen so that lengths and heights are non-negative.

# %% [markdown]
# <a name='2-3'></a>
# ### 2.3 - Non-max Suppression
#
# Even after filtering by thresholding over the class scores, you still end up with a lot of overlapping boxes. A second filter for selecting the right boxes is called non-maximum suppression (NMS).

# %% [markdown]
# <img src="nb_images/non-max-suppression.png" style="width:500px;height:400;">
# <caption><center> <u> <b>Figure 7</b> </u>: In this example, the model has predicted 3 cars, but it's actually 3 predictions of the same car. Running non-max suppression (NMS) will select only the most accurate (highest probability) of the 3 boxes. <br> </center></caption>

# %% [markdown]
# Non-max suppression uses the very important function called **"Intersection over Union"**, or IoU.
# <img src="nb_images/iou.png" style="width:500px;height:400;">
# <caption><center> <u> <b>Figure 8</b> </u>: Definition of "Intersection over Union". <br> </center></caption>
#
# <a name='ex-2'></a>
# ### Exercise 2 - iou
#
# Implement `iou()`
#
# Some hints:
# - This code uses the convention that (0,0) is the top-left corner of an image, (1,0) is the upper-right corner, and (1,1) is the lower-right corner. In other words, the (0,0) origin starts at the top left corner of the image. As x increases, you move to the right.  As y increases, you move down.
# - For this exercise, a box is defined using its two corners: upper left $(x_1, y_1)$ and lower right $(x_2,y_2)$, instead of using the midpoint, height and width. This makes it a bit easier to calculate the intersection.
# - To calculate the area of a rectangle, multiply its height $(y_2 - y_1)$ by its width $(x_2 - x_1)$. Since $(x_1,y_1)$ is the top left and $x_2,y_2$ are the bottom right, these differences should be non-negative.
# - To find the **intersection** of the two boxes $(xi_{1}, yi_{1}, xi_{2}, yi_{2})$:
#     - Feel free to draw some examples on paper to clarify this conceptually.
#     - The top left corner of the intersection $(xi_{1}, yi_{1})$ is found by comparing the top left corners $(x_1, y_1)$ of the two boxes and finding a vertex that has an x-coordinate that is closer to the right, and y-coordinate that is closer to the bottom.
#     - The bottom right corner of the intersection $(xi_{2}, yi_{2})$ is found by comparing the bottom right corners $(x_2,y_2)$ of the two boxes and finding a vertex whose x-coordinate is closer to the left, and the y-coordinate that is closer to the top.
#     - The two boxes **may have no intersection**.  You can detect this if the intersection coordinates you calculate end up being the top right and/or bottom left corners of an intersection box.  Another way to think of this is if you calculate the height $(y_2 - y_1)$ or width $(x_2 - x_1)$ and find that at least one of these lengths is negative, then there is no intersection (intersection area is zero).
#     - The two boxes may intersect at the **edges or vertices**, in which case the intersection area is still zero.  This happens when either the height or width (or both) of the calculated intersection is zero.
#
#
# **Additional Hints**
#
# - `xi1` = **max**imum of the x1 coordinates of the two boxes
# - `yi1` = **max**imum of the y1 coordinates of the two boxes
# - `xi2` = **min**imum of the x2 coordinates of the two boxes
# - `yi2` = **min**imum of the y2 coordinates of the two boxes
# - `inter_area` = You can use `max(height, 0)` and `max(width, 0)`

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: iou

def iou(box1, box2):
    """Implement the intersection over union (IoU) between box1 and box2

    Arguments:
    box1 -- first box, list object with coordinates (box1_x1, box1_y1, box1_x2, box_1_y2)
    box2 -- second box, list object with coordinates (box2_x1, box2_y1, box2_x2, box2_y2)
    """


    (box1_x1, box1_y1, box1_x2, box1_y2) = box1
    (box2_x1, box2_y1, box2_x2, box2_y2) = box2

    ### START CODE HERE
    # Calculate the (yi1, xi1, yi2, xi2) coordinates of the intersection of box1 and box2. Calculate its Area.
    ##(≈ 7 lines)
    xi1 = max(box1_x1, box2_x1)
    yi1 = max(box1_y1, box2_y1)
    xi2 = min(box1_x2, box2_x2)
    yi2 = min(box1_y2, box2_y2)
    inter_width = xi2 - xi1
    inter_height = yi2 - yi1
    inter_area = max(inter_width, 0) * max(inter_height, 0)

    # Calculate the Union area by using Formula: Union(A,B) = A + B - Inter(A,B)
    ## (≈ 3 lines)
    box1_area = (box1_x2 - box1_x1) * (box1_y2 - box1_y1)
    box2_area = (box2_x2 - box2_x1) * (box2_y2 - box2_y1)
    union_area = box1_area + box2_area - inter_area

    # compute the IoU
    iou = inter_area / union_area
    ### END CODE HERE

    return iou

# %%
# BEGIN UNIT TEST
## Test case 1: boxes intersect
box1 = (2, 1, 4, 3)
box2 = (1, 2, 3, 4)

print("iou for intersecting boxes = " + str(iou(box1, box2)))
assert iou(box1, box2) < 1, "The intersection area must be always smaller or equal than the union area."
assert np.isclose(iou(box1, box2), 0.14285714), "Wrong value. Check your implementation. Problem with intersecting boxes"

## Test case 2: boxes do not intersect
box1 = (1,2,3,4)
box2 = (5,6,7,8)
print("iou for non-intersecting boxes = " + str(iou(box1,box2)))
assert iou(box1, box2) == 0, "Intersection must be 0"

## Test case 3: boxes intersect at vertices only
box1 = (1,1,2,2)
box2 = (2,2,3,3)
print("iou for boxes that only touch at vertices = " + str(iou(box1,box2)))
assert iou(box1, box2) == 0, "Intersection at vertices must be 0"

## Test case 4: boxes intersect at edge only
box1 = (1,1,3,3)
box2 = (2,3,3,4)
print("iou for boxes that only touch at edges = " + str(iou(box1,box2)))
assert iou(box1, box2) == 0, "Intersection at edges must be 0"

print("\033[92m All tests passed!")
# END UNIT TEST
# Out:
# iou for intersecting boxes = 0.14285714285714285
# iou for non-intersecting boxes = 0.0
# iou for boxes that only touch at vertices = 0.0
# iou for boxes that only touch at edges = 0.0
#  All tests passed!

# %% [markdown]
# **Expected Output**:
#
# ```
# iou for intersecting boxes = 0.14285714285714285
# iou for non-intersecting boxes = 0.0
# iou for boxes that only touch at vertices = 0.0
# iou for boxes that only touch at edges = 0.0
# ```

# %% [markdown]
# <a name='2-4'></a>
# ### 2.4 - YOLO Non-max Suppression
#
# You are now ready to implement non-max suppression. The key steps are:
# 1. Select the box that has the highest score.
# 2. Compute the overlap of this box with all other boxes, and remove boxes that overlap significantly (iou >= `iou_threshold`).
# 3. Go back to step 1 and iterate until there are no more boxes with a lower score than the currently selected box.
#
# This will remove all boxes that have a large overlap with the selected boxes. Only the "best" boxes remain.
#
# <a name='ex-3'></a>
# ### Exercise 3 - yolo_non_max_suppression
#
# Implement `yolo_non_max_suppression()` using TensorFlow. TensorFlow has two built-in functions that are used to implement non-max suppression (so you don't actually need to use your `iou()` implementation):
#
# **Reference documentation**:
#
# - [tf.image.non_max_suppression()](https://www.tensorflow.org/api_docs/python/tf/image/non_max_suppression)
# ```
# tf.image.non_max_suppression(
#     boxes,
#     scores,
#     max_output_size,
#     iou_threshold=0.5,
#     name=None
# )
# ```
# Note that in the version of TensorFlow used here, there is no parameter `score_threshold` (it's shown in the documentation for the latest version) so trying to set this value will result in an error message: *got an unexpected keyword argument `score_threshold`.*
#
# - [tf.gather()](https://www.tensorflow.org/api_docs/python/tf/gather)
# ```
# keras.gather(
#     reference,
#     indices
# )
# ```

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: yolo_non_max_suppression

def yolo_non_max_suppression(scores, boxes, classes, max_boxes = 10, iou_threshold = 0.5):
    """
    Applies Non-max suppression (NMS) to set of boxes

    Arguments:
    scores -- tensor of shape (None,), output of yolo_filter_boxes()
    boxes -- tensor of shape (None, 4), output of yolo_filter_boxes() that have been scaled to the image size (see later)
    classes -- tensor of shape (None,), output of yolo_filter_boxes()
    max_boxes -- integer, maximum number of predicted boxes you'd like
    iou_threshold -- real value, "intersection over union" threshold used for NMS filtering

    Returns:
    scores -- tensor of shape (None, ), predicted score for each box
    boxes -- tensor of shape (None, 4), predicted box coordinates
    classes -- tensor of shape (None, ), predicted class for each box

    Note: The "None" dimension of the output tensors has obviously to be less than max_boxes. Note also that this
    function will transpose the shapes of scores, boxes, classes. This is made for convenience.
    """

    max_boxes_tensor = tf.Variable(max_boxes, dtype='int32')     # tensor to be used in tf.image.non_max_suppression()

    ### START CODE HERE
    # Use tf.image.non_max_suppression() to get the list of indices corresponding to boxes you keep
    ##(≈ 1 line)
    nms_indices = tf.image.non_max_suppression(boxes, scores, max_boxes_tensor, iou_threshold=iou_threshold)

    # Use tf.gather() to select only nms_indices from scores, boxes and classes
    ##(≈ 3 lines)
    scores = tf.gather(scores, nms_indices)
    boxes = tf.gather(boxes, nms_indices)
    classes = tf.gather(classes, nms_indices)
    ### END CODE HERE


    return scores, boxes, classes

# %%
# BEGIN UNIT TEST
tf.random.set_seed(10)
scores = tf.random.normal([54,], mean=1, stddev=4, seed = 1)
boxes = tf.random.normal([54, 4], mean=1, stddev=4, seed = 1)
classes = tf.random.normal([54,], mean=1, stddev=4, seed = 1)
scores, boxes, classes = yolo_non_max_suppression(scores, boxes, classes)

assert type(scores) == EagerTensor, "Use tensoflow functions"
print("scores[2] = " + str(scores[2].numpy()))
print("boxes[2] = " + str(boxes[2].numpy()))
print("classes[2] = " + str(classes[2].numpy()))
print("scores.shape = " + str(scores.numpy().shape))
print("boxes.shape = " + str(boxes.numpy().shape))
print("classes.shape = " + str(classes.numpy().shape))

assert type(scores) == EagerTensor, "Use tensoflow functions"
assert type(boxes) == EagerTensor, "Use tensoflow functions"
assert type(classes) == EagerTensor, "Use tensoflow functions"

assert scores.shape == (10,), "Wrong shape"
assert boxes.shape == (10, 4), "Wrong shape"
assert classes.shape == (10,), "Wrong shape"

assert np.isclose(scores[2].numpy(), 8.147684), "Wrong value on scores"
assert np.allclose(boxes[2].numpy(), [ 6.0797963, 3.743308, 1.3914018, -0.34089637]), "Wrong value on boxes"
assert np.isclose(classes[2].numpy(), 1.7079165), "Wrong value on classes"

print("\033[92m All tests passed!")
# END UNIT TEST
# Out:
# scores[2] = 8.147684
# boxes[2] = [ 6.0797963   3.7433083   1.3914018  -0.34089637]
# classes[2] = 1.7079165
# scores.shape = (10,)
# boxes.shape = (10, 4)
# classes.shape = (10,)
#  All tests passed!

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#             <b>scores[2]</b>
#         </td>
#         <td>
#            8.147684
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>boxes[2]</b>
#         </td>
#         <td>
#            [ 6.0797963   3.743308    1.3914018  -0.34089637]
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>classes[2]</b>
#         </td>
#         <td>
#            1.7079165
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <b>scores.shape</b>
#         </td>
#         <td>
#            (10,)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>boxes.shape</b>
#         </td>
#         <td>
#            (10, 4)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>classes.shape</b>
#         </td>
#         <td>
#            (10,)
#         </td>
#     </tr>
#
# </table>

# %% [markdown]
# <a name='2-5'></a>
# ### 2.5 - Wrapping Up the Filtering
#
# It's time to implement a function taking the output of the deep CNN (the 19x19x5x85 dimensional encoding) and filtering through all the boxes using the functions you've just implemented.
#
# <a name='ex-4'></a>
# ### Exercise 4 - yolo_eval
#
# Implement `yolo_eval()` which takes the output of the YOLO encoding and filters the boxes using score threshold and NMS. There's just one last implementational detail you have to know. There're a few ways of representing boxes, such as via their corners or via their midpoint and height/width. YOLO converts between a few such formats at different times, using the following functions (which are provided):
#
# ```python
# boxes = yolo_boxes_to_corners(box_xy, box_wh)
# ```
# which converts the yolo box coordinates (x,y,w,h) to box corners' coordinates (x1, y1, x2, y2) to fit the input of `yolo_filter_boxes`
# ```python
# boxes = scale_boxes(boxes, image_shape)
# ```
# YOLO's network was trained to run on 608x608 images. If you are testing this data on a different size image -- for example, the car detection dataset had 720x1280 images -- this step rescales the boxes so that they can be plotted on top of the original 720x1280 image.
#
# Don't worry about these two functions; you'll see where they need to be called below.
#
# Mục tiêu của yolo_eval()
# Hàm yolo_eval() có nhiệm vụ lấy đầu ra của mạng YOLO (có dạng tensor kích thước 19×19×5×85) và thực hiện các bước xử lý sau:
#
# Lọc các bounding boxes dựa trên score threshold và NMS (Non-Maximum Suppression).
# Chuyển đổi format tọa độ bounding box từ (x, y, w, h) sang (x1, y1, x2, y2).  (toạ độ 2 góc của box đễ dễ vẽ)
# Tỉ lệ lại bounding boxes để phù hợp với kích thước ảnh gốc.

# %%
def yolo_boxes_to_corners(box_xy, box_wh):
    """Convert YOLO box predictions to bounding box corners."""
    box_mins = box_xy - (box_wh / 2.)
    box_maxes = box_xy + (box_wh / 2.)

    return tf.keras.backend.concatenate([
        box_mins[..., 1:2],  # y_min
        box_mins[..., 0:1],  # x_min
        box_maxes[..., 1:2],  # y_max
        box_maxes[..., 0:1]  # x_max
    ])

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: yolo_eval

def yolo_eval(yolo_outputs, image_shape = (720, 1280), max_boxes=10, score_threshold=.6, iou_threshold=.5):
    """
    Converts the output of YOLO encoding (a lot of boxes) to your predicted boxes along with their scores, box coordinates and classes.

    Arguments:
    yolo_outputs -- output of the encoding model (for image_shape of (608, 608, 3)), contains 4 tensors:
                    box_xy: tensor of shape (None, 19, 19, 5, 2)
                    box_wh: tensor of shape (None, 19, 19, 5, 2)
                    box_confidence: tensor of shape (None, 19, 19, 5, 1)
                    box_class_probs: tensor of shape (None, 19, 19, 5, 80)
    image_shape -- tensor of shape (2,) containing the input shape, in this notebook we use (608., 608.) (has to be float32 dtype)
    max_boxes -- integer, maximum number of predicted boxes you'd like
    score_threshold -- real value, if [ highest class probability score < threshold], then get rid of the corresponding box
    iou_threshold -- real value, "intersection over union" threshold used for NMS filtering

    Returns:
    scores -- tensor of shape (None, ), predicted score for each box
    boxes -- tensor of shape (None, 4), predicted box coordinates
    classes -- tensor of shape (None,), predicted class for each box
    """

    ### START CODE HERE
    # Retrieve outputs of the YOLO model (≈1 line)
    box_xy, box_wh, box_confidence, box_class_probs = yolo_outputs

    # Convert boxes to be ready for filtering functions (convert boxes box_xy and box_wh to corner coordinates)
    boxes = yolo_boxes_to_corners(box_xy, box_wh)

    # Use one of the functions you've implemented to perform Score-filtering with a threshold of score_threshold (≈1 line)
    scores, boxes, classes = yolo_filter_boxes(boxes, box_confidence, box_class_probs, threshold=score_threshold)

    # Scale boxes back to original image shape.
    boxes = scale_boxes(boxes, image_shape)

    # Use one of the functions you've implemented to perform Non-max suppression with
    # maximum number of boxes set to max_boxes and a threshold of iou_threshold (≈1 line)
    scores, boxes, classes = yolo_non_max_suppression(scores, boxes, classes, max_boxes=max_boxes, iou_threshold=iou_threshold)
    ### END CODE HERE

    return scores, boxes, classes

# %%
# BEGIN UNIT TEST
tf.random.set_seed(10)
yolo_outputs = (tf.random.normal([19, 19, 5, 2], mean=1, stddev=4, seed = 1),
                tf.random.normal([19, 19, 5, 2], mean=1, stddev=4, seed = 1),
                tf.random.normal([19, 19, 5, 1], mean=1, stddev=4, seed = 1),
                tf.random.normal([19, 19, 5, 80], mean=1, stddev=4, seed = 1))
scores, boxes, classes = yolo_eval(yolo_outputs)
print("scores[2] = " + str(scores[2].numpy()))
print("boxes[2] = " + str(boxes[2].numpy()))
print("classes[2] = " + str(classes[2].numpy()))
print("scores.shape = " + str(scores.numpy().shape))
print("boxes.shape = " + str(boxes.numpy().shape))
print("classes.shape = " + str(classes.numpy().shape))

assert type(scores) == EagerTensor, "Use tensoflow functions"
assert type(boxes) == EagerTensor, "Use tensoflow functions"
assert type(classes) == EagerTensor, "Use tensoflow functions"

assert scores.shape == (10,), "Wrong shape"
assert boxes.shape == (10, 4), "Wrong shape"
assert classes.shape == (10,), "Wrong shape"

assert np.isclose(scores[2].numpy(), 171.60194), "Wrong value on scores"
assert np.allclose(boxes[2].numpy(), [-1240.3483, -3212.5881, -645.78, 2024.3052]), "Wrong value on boxes"
assert np.isclose(classes[2].numpy(), 16), "Wrong value on classes"

print("\033[92m All tests passed!")
# END UNIT TEST
# Out:
# scores[2] = 171.60194
# boxes[2] = [-1240.3481 -3212.588   -645.7799  2024.3053]
# classes[2] = 16
# scores.shape = (10,)
# boxes.shape = (10, 4)
# classes.shape = (10,)
#  All tests passed!

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#             <b>scores[2]</b>
#         </td>
#         <td>
#            171.60194
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>boxes[2]</b>
#         </td>
#         <td>
#            [-1240.3483 -3212.5881  -645.78    2024.3052]
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>classes[2]</b>
#         </td>
#         <td>
#            16
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <b>scores.shape</b>
#         </td>
#         <td>
#            (10,)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>boxes.shape</b>
#         </td>
#         <td>
#            (10, 4)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>classes.shape</b>
#         </td>
#         <td>
#            (10,)
#         </td>
#     </tr>
#
# </table>

# %% [markdown]
# <a name='3'></a>
# ## 3 - Test YOLO Pre-trained Model on Images
#
# In this section, you are going to use a pre-trained model and test it on the car detection dataset.

# %% [markdown]
# <a name='3-1'></a>
# ### 3.1 - Defining Classes, Anchors and Image Shape
#
# You're trying to detect 80 classes, and are using 5 anchor boxes. The information on the 80 classes and 5 boxes is gathered in two files: "coco_classes.txt" and "yolo_anchors.txt". You'll read class names and anchors from text files. The car detection dataset has 720x1280 images, which are pre-processed into 608x608 images.

# %%
def load_classes(classes_path):
    with open(classes_path) as f:
        return [c.strip() for c in f.readlines()]

def load_anchors(anchors_path):
    with open(anchors_path) as f:
        anchors = f.readline().split(',')
        anchors = [float(x) for x in anchors]
        return np.array(anchors).reshape(-1, 2)

# %%
classes_path = os.path.join(BASE_URL, "model_data", "coco_classes.txt")
anchors_path = os.path.join(BASE_URL, "model_data", "yolo_anchors.txt")

class_names = load_classes(classes_path)
anchors = load_anchors(anchors_path)

model_image_size = (608, 608)

# %% [markdown]
# <a name='3-2'></a>
# ### 3.2 - Loading a Pre-trained Model
#
# Training a YOLO model takes a very long time and requires a fairly large dataset of labelled bounding boxes for a large range of target classes. You are going to load an existing pre-trained Keras YOLO model stored in "yolo.h5". These weights come from the official YOLO website, and were converted using a function written by Allan Zelener. References are at the end of this notebook. Technically, these are the parameters from the "YOLOv2" model, but are simply referred to as "YOLO" in this notebook.
#
# Run the cell below to load the model from this file.

# %%
model_path = os.path.join(BASE_URL, "yolov2.h5")
yolo_model = load_model(model_path, compile=False)

# %% [markdown]
# This loads the weights of a trained YOLO model. Here's a summary of the layers your model contains:

# %%
yolo_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 608, 608,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 608, 608,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 608, 608,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 608, 608,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 304, 304,  │          0 │ leaky_re_lu[0][0] │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 304, 304,  │     18,432 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 304, 304,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 304, 304,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 152, 152,  │          0 │ leaky_re_lu_1[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 152, 152,  │     73,728 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 152, 152,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_2       │ (None, 152, 152,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 152, 152,  │      8,192 │ leaky_re_lu_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 152, 152,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_3       │ (None, 152, 152,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 152, 152,  │     73,728 │ leaky_re_lu_3[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 152, 152,  │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_4       │ (None, 152, 152,  │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 76, 76,    │          0 │ leaky_re_lu_4[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 76, 76,    │    294,912 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 76, 76,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_5       │ (None, 76, 76,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 76, 76,    │     32,768 │ leaky_re_lu_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 76, 76,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_6       │ (None, 76, 76,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 76, 76,    │    294,912 │ leaky_re_lu_6[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 76, 76,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_7       │ (None, 76, 76,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 38, 38,    │          0 │ leaky_re_lu_7[0]… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 38, 38,    │  1,179,648 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_8       │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 38, 38,    │    131,072 │ leaky_re_lu_8[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_9       │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 38, 38,    │  1,179,648 │ leaky_re_lu_9[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │      2,048 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_10      │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 38, 38,    │    131,072 │ leaky_re_lu_10[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_11      │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 38, 38,    │  1,179,648 │ leaky_re_lu_11[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │      2,048 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_12      │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 19, 19,    │          0 │ leaky_re_lu_12[0… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 19, 19,    │  4,718,592 │ max_pooling2d_4[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      4,096 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_13      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 19, 19,    │    524,288 │ leaky_re_lu_13[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      2,048 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_14      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 19, 19,    │  4,718,592 │ leaky_re_lu_14[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      4,096 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_15      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 19, 19,    │    524,288 │ leaky_re_lu_15[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      2,048 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_16      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 19, 19,    │  4,718,592 │ leaky_re_lu_16[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      4,096 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_17      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 19, 19,    │  9,437,184 │ leaky_re_lu_17[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      4,096 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 38, 38,    │     32,768 │ leaky_re_lu_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_18      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 38, 38,    │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 19, 19,    │  9,437,184 │ leaky_re_lu_18[0… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_20      │ (None, 38, 38,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      4,096 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ space_to_depth_x2   │ (None, 19, 19,    │          0 │ leaky_re_lu_20[0… │
# │ (Lambda)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_19      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 19, 19,    │          0 │ space_to_depth_x… │
# │ (Concatenate)       │ 1280)             │            │ leaky_re_lu_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 19, 19,    │ 11,796,480 │ concatenate[0][0] │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 19, 19,    │      4,096 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_21      │ (None, 19, 19,    │          0 │ batch_normalizat… │
# │ (LeakyReLU)         │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 19, 19,    │    435,625 │ leaky_re_lu_21[0… │
# │                     │ 425)              │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 50,983,561 (194.49 MB)
#  Trainable params: 50,962,889 (194.41 MB)
#  Non-trainable params: 20,672 (80.75 KB)

# %% [markdown]
# **Note**: On some computers, you may see a warning message from Keras. Don't worry about it if you do -- this is fine!
#
# **Reminder**: This model converts a preprocessed batch of input images (shape: (m, 608, 608, 3)) into a tensor of shape (m, 19, 19, 5, 85) as explained in Figure (2).

# %% [markdown]
# <a name='3-3'></a>
# ### 3.3 - Convert Output of the Model to Usable Bounding Box Tensors
#
# The output of `yolo_model` is a (m, 19, 19, 5, 85) tensor that needs to pass through non-trivial processing and conversion. You will need to call `yolo_head` to format the encoding of the model you got from `yolo_model` into something decipherable:
#
# yolo_model_outputs = yolo_model(image_data)
# yolo_outputs = yolo_head(yolo_model_outputs, anchors, len(class_names))
# The variable `yolo_outputs` will be defined as a set of 4 tensors that you can then use as input by your yolo_eval function. If you are curious about how yolo_head is implemented, you can find the function definition in the file `keras_yolo.py`. The file is also located in your workspace in this path: `yad2k/models/keras_yolo.py`.

# %% [markdown]
# <a name='3-4'></a>
# ### 3.4 - Filtering Boxes
#
# `yolo_outputs` gave you all the predicted boxes of `yolo_model` in the correct format. To perform filtering and select only the best boxes, you will call `yolo_eval`, which you had previously implemented, to do so:
#
#     out_scores, out_boxes, out_classes = yolo_eval(yolo_outputs, [image.size[1],  image.size[0]], 10, 0.3, 0.5)

# %% [markdown]
# <a name='3-5'></a>
# ### 3.5 - Run the YOLO on an Image
#
# Let the fun begin! You will create a graph that can be summarized as follows:
#
# `yolo_model.input` is given to `yolo_model`. The model is used to compute the output `yolo_model.output`
# `yolo_model.output` is processed by `yolo_head`. It gives you `yolo_outputs`
# `yolo_outputs` goes through a filtering function, `yolo_eval`. It outputs your predictions: `out_scores`, `out_boxes`, `out_classes`.

# %% [markdown]
# Now, we have implemented for you the `predict(image_file)` function, which runs the graph to test YOLO on an image to compute `out_scores`, `out_boxes`, `out_classes`.
#
# The code below also uses the following function:
#
#     image, image_data = preprocess_image("images/" + image_file, model_image_size = (608, 608))
# which opens the image file and scales, reshapes and normalizes the image. It returns the outputs:
#
#     image: a python (PIL) representation of your image used for drawing boxes. You won't need to use it.
#     image_data: a numpy-array representing the image. This will be the input to the CNN.

# %%
def predict(image_file):

    input_images_path = os.path.join(BASE_URL, "images", image_file)
    output_images_path = os.path.join(BASE_URL, "out", image_file)

    # Preprocess
    image, image_data = preprocess_image(
        input_images_path,
        model_image_size=(608, 608)
    )

    # Forward
    yolo_model_output = yolo_model(image_data)

    # Decode YOLOv2
    yolo_outputs = yolo_head(
        yolo_model_output,
        anchors,
        len(class_names)
    )

    # Evaluate
    out_scores, out_boxes, out_classes = yolo_eval(
        yolo_outputs,
        [float(image.size[1]), float(image.size[0])],
        max_boxes=10,
        score_threshold=0.3,
        iou_threshold=0.5
    )

    print(f"Found {len(out_boxes)} boxes for {input_images_path}")

    # Tensor → numpy
    if hasattr(out_scores, "numpy"):
        out_scores = out_scores.numpy()
    if hasattr(out_boxes, "numpy"):
        out_boxes = out_boxes.numpy()
    if hasattr(out_classes, "numpy"):
        out_classes = out_classes.numpy()

    # ⚠️ QUAN TRỌNG
    # draw_boxes yêu cầu image dạng [0–1]
    image_np = np.array(image, dtype=np.float32) / 255.0

    image_with_boxes = draw_boxes(
        image_np,
        out_boxes,
        out_classes,
        class_names,
        out_scores
    )  # ← ĐÃ LÀ uint8 PIL-safe

    # Vẽ thêm label + confidence
    image_pil = Image.fromarray(image_with_boxes)

    image_pil.save(output_images_path, quality=100)
    imshow(image_pil)

    return out_scores, out_boxes, out_classes

# %%
from PIL import ImageDraw

# Monkey-patch cho Pillow >= 10 (để YAD2K chạy được)
if not hasattr(ImageDraw.ImageDraw, "textsize"):
    def textsize(self, text, font=None):
        bbox = self.textbbox((0, 0), text, font=font)
        width = bbox[2] - bbox[0]
        height = bbox[3] - bbox[1]
        return (width, height)

    ImageDraw.ImageDraw.textsize = textsize

# %% [markdown]
# Run the following cell on the "test.jpg" image to verify that your function is correct.

# %%
out_scores, out_boxes, out_classes = predict("test.jpg")
# Out:
# Found 10 boxes for /content/drive/MyDrive/Colab Notebooks/DPL/Lab/Lab1/Lab_3_full_v1/images/test.jpg
# car 0.89 (np.int32(366), np.int32(299)) (np.int32(745), np.int32(648))
# car 0.80 (np.int32(762), np.int32(282)) (np.int32(942), np.int32(412))
# car 0.75 (np.int32(159), np.int32(303)) (np.int32(346), np.int32(440))
# car 0.70 (np.int32(947), np.int32(324)) (1280, np.int32(704))
# car 0.68 (np.int32(705), np.int32(279)) (np.int32(786), np.int32(351))
# bus 0.67 (np.int32(5), np.int32(267)) (np.int32(220), np.int32(407))
# car 0.60 (np.int32(925), np.int32(285)) (np.int32(1045), np.int32(374))
# car 0.45 (np.int32(336), np.int32(296)) (np.int32(377), np.int32(335))
# car 0.38 (np.int32(965), np.int32(273)) (np.int32(1023), np.int32(292))
# traffic light 0.35 (np.int32(681), np.int32(195)) (np.int32(692), np.int32(215))

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#             <b>Found 10 boxes for images/test.jpg</b>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.89 (367, 300) (745, 648)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.80 (761, 282) (942, 412)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.74 (159, 303) (346, 440)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#           0.70 (947, 324) (1280, 705)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>bus</b>
#         </td>
#         <td>
#            0.67 (5, 266) (220, 407)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.66 (706, 279) (786, 350)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.60 (925, 285) (1045, 374)
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.44 (336, 296) (378, 335)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>car</b>
#         </td>
#         <td>
#            0.37 (965, 273) (1022, 292)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <b>traffic light</b>
#         </td>
#         <td>
#            00.36 (681, 195) (692, 214)
#         </td>
#     </tr>
# </table>

# %% [markdown]
# The model you've just run is actually able to detect 80 different classes listed in "coco_classes.txt". To test the model on your own images:
#     1. Click on "File" in the upper bar of this notebook, then click "Open" to go on your Coursera Hub.
#     2. Add your image to this Jupyter Notebook's directory, in the "images" folder
#     3. Write your image's name in the cell above code
#     4. Run the code and see the output of the algorithm!
#
# If you were to run your session in a for loop over all your images. Here's what you would get:
#
# <center>
# <video width="400" height="200" src="nb_images/pred_video_compressed2.mp4" type="video/mp4" controls>
# </video>
# </center>
#
# <caption><center> Predictions of the YOLO model on pictures taken from a camera while driving around the Silicon Valley <br> Thanks to <a href="https://www.drive.ai/">drive.ai</a> for providing this dataset! </center></caption>

# %%
def predict_video(
    video_path,
    output_path,
    model_image_size=(608, 608),
    score_threshold=0.3,
    iou_threshold=0.5,
    max_boxes=10
):
    import cv2
    import time
    import numpy as np
    from PIL import Image

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise ValueError(f"Cannot open video: {video_path}")

    # ---- Video info ----
    fps_in = cap.get(cv2.CAP_PROP_FPS)
    if fps_in is None or fps_in <= 1:
        fps_in = 25.0

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    writer = cv2.VideoWriter(output_path, fourcc, fps_in, (width, height))

    frame_count = 0
    prev_time = time.time()

    while True:
        ret, frame_bgr = cap.read()
        if not ret:
            break

        frame_count += 1

        # ---- Timing start ----
        t_start = time.time()

        # ---- BGR → RGB → PIL ----
        frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(frame_rgb)

        # ---- Preprocess ----
        image_resized = image.resize(model_image_size)
        image_data = np.array(image_resized, dtype=np.float32) / 255.0
        image_data = np.expand_dims(image_data, axis=0)

        # ---- YOLO forward ----
        yolo_output = yolo_model(image_data)
        yolo_outputs = yolo_head(yolo_output, anchors, len(class_names))

        out_scores, out_boxes, out_classes = yolo_eval(
            yolo_outputs,
            [float(image.size[1]), float(image.size[0])],
            max_boxes=max_boxes,
            score_threshold=score_threshold,
            iou_threshold=iou_threshold
        )

        # Tensor → numpy
        if hasattr(out_scores, "numpy"):
            out_scores = out_scores.numpy()
        if hasattr(out_boxes, "numpy"):
            out_boxes = out_boxes.numpy()
        if hasattr(out_classes, "numpy"):
            out_classes = out_classes.numpy()

        # ---- Draw boxes + confidence ----
        image_np = np.array(image, dtype=np.float32) / 255.0
        image_with_boxes = draw_boxes(
            image_np,
            out_boxes,
            out_classes,
            class_names,
            out_scores
        )

        # ---- Back to OpenCV ----
        frame_out = cv2.cvtColor(
            image_with_boxes.astype("uint8"),
            cv2.COLOR_RGB2BGR
        )

        # ---- Timing end ----
        inf_time = time.time() - t_start
        fps_now = 1.0 / max(inf_time, 1e-6)

        # ---- Draw FPS (top-left) ----
        cv2.putText(
            frame_out,
            f"FPS: {fps_now:.2f}",
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.9,
            (0, 255, 0),
            2,
            cv2.LINE_AA
        )

        writer.write(frame_out)

        # ---- Console log (THEO ĐÚNG FORMAT BẠN MUỐN) ----
        print(
            f"Frame {frame_count}/{total_frames} - "
            f"{inf_time*1000:.1f} ms - FPS {fps_now:.2f}"
        )

    cap.release()
    writer.release()
    print(f"✅ Saved output video to: {output_path}")

# %%
video_file = "Test_video.mp4"

input_images_path = os.path.join(BASE_URL, "videos", video_file)
output_images_path = os.path.join(BASE_URL, "out", video_file)

predict_video(
    video_path=input_images_path,
    output_path=output_images_path,
    score_threshold=0.3,
    iou_threshold=0.5
)
# Out:
# car 0.71 (np.int32(9), np.int32(403)) (np.int32(152), np.int32(492))
# car 0.49 (np.int32(203), np.int32(411)) (np.int32(239), np.int32(437))
# car 0.34 (np.int32(126), np.int32(408)) (np.int32(161), np.int32(441))
# Frame 1/447 - 120.0 ms - FPS 8.33
# car 0.70 (np.int32(9), np.int32(401)) (np.int32(151), np.int32(495))
# car 0.54 (np.int32(202), np.int32(411)) (np.int32(239), np.int32(437))
# car 0.43 (np.int32(125), np.int32(407)) (np.int32(161), np.int32(441))
# Frame 2/447 - 111.0 ms - FPS 9.01
# car 0.70 (0, np.int32(396)) (np.int32(146), np.int32(497))
# car 0.54 (np.int32(202), np.int32(411)) (np.int32(240), np.int32(438))
# car 0.41 (np.int32(129), np.int32(406)) (np.int32(162), np.int32(438))
# Frame 3/447 - 163.2 ms - FPS 6.13
# car 0.72 (0, np.int32(397)) (np.int32(143), np.int32(498))
# car 0.57 (np.int32(205), np.int32(412)) (np.int32(242), np.int32(438))
# car 0.47 (np.int32(131), np.int32(403)) (np.int32(165), np.int32(434))
# Frame 4/447 - 215.0 ms - FPS 4.65
# car 0.74 (0, np.int32(398)) (np.int32(140), np.int32(497))
# car 0.55 (np.int32(212), np.int32(414)) (np.int32(247), np.int32(440))
# car 0.54 (np.int32(126), np.int32(403)) (np.int32(169), np.int32(434))
# Frame 5/447 - 241.7 ms - FPS 4.14
# car 0.77 (0, np.int32(400)) (np.int32(139), np.int32(498))
# car 0.64 (np.int32(212), np.int32(415)) (np.int32(246), np.int32(441))
# car 0.53 (np.int32(123), np.int32(403)) (np.int32(172), np.int32(434))
# Frame 6/447 - 181.3 ms - FPS 5.51
# car 0.78 (0, np.int32(400)) (np.int32(136), np.int32(498))
# car 0.64 (np.int32(212), np.int32(414)) (np.int32(247), np.int32(440))
# car 0.58 (np.int32(121), np.int32(402)) (np.int32(172), np.int32(434))
# Frame 7/447 - 192.6 ms - FPS 5.19
# car 0.79 (0, np.int32(398)) (np.int32(131), np.int32(499))
# car 0.67 (np.int32(212), np.int32(413)) (np.int32(248), np.int32(440))
# car 0.61 (np.int32(123), np.int32(402)) (np.int32(173), np.int32(434))
# car 0.30 (np.int32(207), np.int32(413)) (np.int32(223), np.int32(433))
# Frame 8/447 - 247.6 ms - FPS 4.04
# car 0.81 (0, np.int32(398)) (np.int32(131), np.int32(500))
# car 0.70 (np.int32(212), np.int32(414)) (np.int32(248), np.int32(441))
# car 0.60 (np.int32(124), np.int32(401)) (np.int32(174), np.int32(434))
# car 0.30 (np.int32(284), np.int32(410)) (np.int32(300), np.int32(428))
# Frame 9/447 - 265.3 ms - FPS 3.77
# car 0.78 (0, np.int32(402)) (np.int32(124), np.int32(501))
# car 0.71 (np.int32(212), np.int32(415)) (np.int32(249), np.int32(443))
# car 0.53 (np.int32(128), np.int32(405)) (np.int32(179), np.int32(434))
# car 0.33 (np.int32(284), np.int32(411)) (np.int32(300), np.int32(429))
# Frame 10/447 - 285.3 ms - FPS 3.51
# car 0.77 (0, np.int32(404)) (np.int32(122), np.int32(504))
# car 0.73 (np.int32(212), np.int32(415)) (np.int32(249), np.int32(444))
# car 0.65 (np.int32(127), np.int32(406)) (np.int32(180), np.int32(436))
# Frame 11/447 - 182.5 ms - FPS 5.48
# car 0.77 (0, np.int32(406)) (np.int32(111), np.int32(510))
# car 0.69 (np.int32(212), np.int32(414)) (np.int32(251), np.int32(444))
# car 0.68 (np.int32(128), np.int32(402)) (np.int32(182), np.int32(436))
# Frame 12/447 - 286.6 ms - FPS 3.49
# car 0.76 (0, np.int32(405)) (np.int32(108), np.int32(510))
# car 0.68 (np.int32(130), np.int32(404)) (np.int32(182), np.int32(436))
# car 0.67 (np.int32(212), np.int32(411)) (np.int32(252), np.int32(443))
# Frame 13/447 - 220.6 ms - FPS 4.53
# car 0.76 (np.int32(1), np.int32(404)) (np.int32(106), np.int32(510))
# car 0.68 (np.int32(129), np.int32(403)) (np.int32(183), np.int32(436))
# car 0.62 (np.int32(211), np.int32(412)) (np.int32(252), np.int32(443))
# Frame 14/447 - 178.3 ms - FPS 5.61
# car 0.73 (np.int32(2), np.int32(406)) (np.int32(100), np.int32(509))
# car 0.69 (np.int32(214), np.int32(414)) (np.int32(254), np.int32(447))
# car 0.66 (np.int32(135), np.int32(403)) (np.int32(186), np.int32(438))
# car 0.50 (np.int32(90), np.int32(415)) (np.int32(107), np.int32(438))
# Frame 15/447 - 251.8 ms - FPS 3.97
# car 0.71 (np.int32(215), np.int32(412)) (np.int32(256), np.int32(448))
# car 0.70 (np.int32(3), np.int32(405)) (np.int32(96), np.int32(507))
# car 0.66 (np.int32(137), np.int32(404)) (np.int32(187), np.int32(437))
# car 0.36 (np.int32(90), np.int32(418)) (np.int32(107), np.int32(437))
# Frame 16/447 - 212.0 ms - FPS 4.72
# car 0.76 (np.int32(2), np.int32(410)) (np.int32(91), np.int32(507))
# car 0.69 (np.int32(215), np.int32(413)) (np.int32(256), np.int32(447))
# car 0.68 (np.int32(137), np.int32(404)) (np.int32(188), np.int32(437))
# car 0.43 (np.int32(89), np.int32(416)) (np.int32(107), np.int32(435))
# car 0.35 (np.int32(82), np.int32(414)) (np.int32(102), np.int32(434))
# Frame 17/447 - 170.3 ms - FPS 5.87
# car 0.74 (np.int32(3), np.int32(411)) (np.int32(86), np.int32(509))
# car 0.69 (np.int32(215), np.int32(411)) (np.int32(256), np.int32(448))
# car 0.68 (np.int32(137), np.int32(404)) (np.int32(189), np.int32(436))
# car 0.32 (np.int32(80), np.int32(415)) (np.int32(101), np.int32(433))
# Frame 18/447 - 232.1 ms - FPS 4.31
# car 0.69 (np.int32(1), np.int32(412)) (np.int32(83), np.int32(509))
# car 0.66 (np.int32(215), np.int32(411)) (np.int32(256), np.int32(448))
# car 0.64 (np.int32(139), np.int32(404)) (np.int32(188), np.int32(437))
# car 0.34 (np.int32(79), np.int32(416)) (np.int32(99), np.int32(434))
# Frame 19/447 - 415.6 ms - FPS 2.41
# car 0.70 (np.int32(214), np.int32(412)) (np.int32(257), np.int32(449))
# car 0.69 (0, np.int32(408)) (np.int32(75), np.int32(511))
# car 0.63 (np.int32(140), np.int32(404)) (np.int32(190), np.int32(438))
# car 0.49 (np.int32(78), np.int32(416)) (np.int32(102), np.int32(437))
# Frame 20/447 - 113.3 ms - FPS 8.82
# car 0.72 (0, np.int32(412)) (np.int32(73), np.int32(512))
# car 0.71 (np.int32(214), np.int32(412)) (np.int32(256), np.int32(449))
# car 0.59 (np.int32(142), np.int32(403)) (np.int32(192), np.int32(437))
# car 0.50 (np.int32(77), np.int32(417)) (np.int32(103), np.int32(436))
# Frame 21/447 - 146.4 ms - FPS 6.83
# car 0.71 (np.int32(212), np.int32(411)) (np.int32(257), np.int32(448))
# car 0.69 (np.int32(1), np.int32(407)) (np.int32(69), np.int32(510))
# car 0.57 (np.int32(147), np.int32(405)) (np.int32(200), np.int32(437))
# car 0.51 (np.int32(77), np.int32(418)) (np.int32(102), np.int32(439))
# Frame 22/447 - 112.7 ms - FPS 8.87
# car 0.76 (0, np.int32(415)) (np.int32(63), np.int32(511))
# car 0.71 (np.int32(213), np.int32(411)) (np.int32(257), np.int32(449))
# car 0.63 (np.int32(146), np.int32(406)) (np.int32(201), np.int32(438))
# car 0.56 (np.int32(76), np.int32(417)) (np.int32(103), np.int32(439))
# car 0.44 (np.int32(52), np.int32(416)) (np.int32(68), np.int32(434))
# Frame 23/447 - 152.0 ms - FPS 6.58
# car 0.74 (np.int32(213), np.int32(412)) (np.int32(257), np.int32(450))
# car 0.69 (0, np.int32(414)) (np.int32(59), np.int32(516))
# car 0.55 (np.int32(77), np.int32(419)) (np.int32(103), np.int32(440))
# car 0.54 (np.int32(150), np.int32(406)) (np.int32(201), np.int32(440))
# car 0.51 (np.int32(47), np.int32(418)) (np.int32(64), np.int32(437))
# car 0.32 (np.int32(53), np.int32(417)) (np.int32(68), np.int32(434))
# Frame 24/447 - 111.3 ms - FPS 8.99
# car 0.76 (np.int32(213), np.int32(411)) (np.int32(257), np.int32(449))
# car 0.71 (np.int32(147), np.int32(403)) (np.int32(203), np.int32(439))
# car 0.63 (0, np.int32(413)) (np.int32(48), np.int32(506))
# car 0.55 (np.int32(78), np.int32(417)) (np.int32(102), np.int32(440))
# car 0.45 (np.int32(39), np.int32(420)) (np.int32(60), np.int32(442))
# car 0.39 (np.int32(31), np.int32(416)) (np.int32(63), np.int32(446))
# car 0.34 (np.int32(56), np.int32(418)) (np.int32(71), np.int32(437))
# Frame 25/447 - 132.3 ms - FPS 7.56
# car 0.75 (np.int32(213), np.int32(408)) (np.int32(257), np.int32(448))
# car 0.69 (np.int32(147), np.int32(403)) (np.int32(204), np.int32(438))
# car 0.55 (np.int32(78), np.int32(417)) (np.int32(102), np.int32(440))
# car 0.54 (np.int32(1), np.int32(411)) (np.int32(43), np.int32(500))
# car 0.44 (np.int32(40), np.int32(419)) (np.int32(59), np.int32(441))
# car 0.38 (np.int32(55), np.int32(418)) (np.int32(71), np.int32(437))
# Frame 26/447 - 110.5 ms - FPS 9.05
# car 0.73 (np.int32(213), np.int32(407)) (np.int32(257), np.int32(448))
# car 0.69 (np.int32(146), np.int32(402)) (np.int32(205), np.int32(438))
# car 0.67 (0, np.int32(408)) (np.int32(37), np.int32(519))
# car 0.53 (np.int32(24), np.int32(419)) (np.int32(59), np.int32(448))
# car 0.48 (np.int32(78), np.int32(417)) (np.int32(100), np.int32(439))
# car 0.37 (np.int32(56), np.int32(417)) (np.int32(72), np.int32(436))
# car 0.33 (np.int32(42), np.int32(420)) (np.int32(59), np.int32(439))
# Frame 27/447 - 123.6 ms - FPS 8.09
# car 0.73 (np.int32(213), np.int32(408)) (np.int32(257), np.int32(448))
# car 0.70 (np.int32(149), np.int32(403)) (np.int32(207), np.int32(438))
# car 0.65 (np.int32(22), np.int32(418)) (np.int32(61), np.int32(448))
# car 0.61 (0, np.int32(408)) (np.int32(28), np.int32(512))
# car 0.41 (np.int32(78), np.int32(417)) (np.int32(100), np.int32(436))
# car 0.33 (np.int32(290), np.int32(397)) (np.int32(326), np.int32(425))
# car 0.31 (np.int32(57), np.int32(416)) (np.int32(72), np.int32(434))
# Frame 28/447 - 112.2 ms - FPS 8.91
# car 0.74 (np.int32(213), np.int32(409)) (np.int32(257), np.int32(448))
# car 0.71 (np.int32(152), np.int32(403)) (np.int32(207), np.int32(438))
# car 0.55 (np.int32(23), np.int32(419)) (np.int32(62), np.int32(445))
# car 0.51 (np.int32(1), np.int32(442)) (np.int32(18), np.int32(521))
# car 0.48 (0, np.int32(418)) (np.int32(22), np.int32(496))
# car 0.46 (np.int32(76), np.int32(419)) (np.int32(100), np.int32(440))
# car 0.34 (np.int32(56), np.int32(417)) (np.int32(72), np.int32(435))
# car 0.30 (np.int32(39), np.int32(419)) (np.int32(61), np.int32(436))
# Frame 29/447 - 121.7 ms - FPS 8.22
# car 0.75 (np.int32(212), np.int32(408)) (np.int32(255), np.int32(450))
# car 0.74 (np.int32(154), np.int32(403)) (np.int32(207), np.int32(438))
# car 0.53 (np.int32(75), np.int32(420)) (np.int32(100), np.int32(441))
# car 0.46 (np.int32(19), np.int32(417)) (np.int32(52), np.int32(447))
# car 0.35 (np.int32(45), np.int32(418)) (np.int32(62), np.int32(436))
# Frame 30/447 - 110.1 ms - FPS 9.08
# car 0.75 (np.int32(211), np.int32(409)) (np.int32(256), np.int32(449))
# car 0.73 (np.int32(155), np.int32(402)) (np.int32(208), np.int32(438))
# car 0.49 (np.int32(76), np.int32(420)) (np.int32(100), np.int32(441))
# car 0.38 (np.int32(17), np.int32(418)) (np.int32(52), np.int32(448))
# car 0.36 (np.int32(44), np.int32(418)) (np.int32(62), np.int32(435))
# car 0.33 (np.int32(57), np.int32(417)) (np.int32(74), np.int32(435))
# Frame 31/447 - 115.7 ms - FPS 8.65
# car 0.74 (np.int32(210), np.int32(408)) (np.int32(256), np.int32(449))
# car 0.69 (np.int32(155), np.int32(401)) (np.int32(208), np.int32(437))
# car 0.59 (np.int32(73), np.int32(421)) (np.int32(99), np.int32(442))
# car 0.55 (np.int32(15), np.int32(420)) (np.int32(52), np.int32(449))
# car 0.39 (np.int32(22), np.int32(416)) (np.int32(65), np.int32(445))
# car 0.36 (np.int32(42), np.int32(419)) (np.int32(62), np.int32(436))
# car 0.36 (np.int32(57), np.int32(417)) (np.int32(74), np.int32(434))
# car 0.32 (np.int32(113), np.int32(413)) (np.int32(128), np.int32(427))
# Frame 32/447 - 127.1 ms - FPS 7.87
# car 0.71 (np.int32(209), np.int32(405)) (np.int32(257), np.int32(448))
# car 0.66 (np.int32(157), np.int32(400)) (np.int32(208), np.int32(437))
# car 0.58 (np.int32(72), np.int32(421)) (np.int32(98), np.int32(442))
# car 0.56 (np.int32(12), np.int32(418)) (np.int32(49), np.int32(450))
# car 0.46 (np.int32(42), np.int32(420)) (np.int32(62), np.int32(438))
# car 0.34 (np.int32(58), np.int32(418)) (np.int32(72), np.int32(434))
# Frame 33/447 - 115.8 ms - FPS 8.63
# car 0.72 (np.int32(208), np.int32(407)) (np.int32(256), np.int32(449))
# car 0.70 (np.int32(157), np.int32(401)) (np.int32(207), np.int32(438))
# car 0.60 (np.int32(69), np.int32(421)) (np.int32(98), np.int32(443))
# car 0.50 (np.int32(10), np.int32(418)) (np.int32(51), np.int32(449))
# car 0.40 (np.int32(21), np.int32(416)) (np.int32(66), np.int32(444))
# car 0.33 (np.int32(56), np.int32(417)) (np.int32(73), np.int32(433))
# car 0.33 (np.int32(40), np.int32(420)) (np.int32(62), np.int32(436))
# Frame 34/447 - 110.5 ms - FPS 9.05
# car 0.73 (np.int32(206), np.int32(407)) (np.int32(257), np.int32(449))
# car 0.67 (np.int32(158), np.int32(399)) (np.int32(208), np.int32(436))
# car 0.62 (np.int32(70), np.int32(421)) (np.int32(97), np.int32(443))
# car 0.52 (np.int32(10), np.int32(419)) (np.int32(49), np.int32(450))
# car 0.44 (np.int32(39), np.int32(420)) (np.int32(61), np.int32(440))
# car 0.34 (np.int32(58), np.int32(417)) (np.int32(74), np.int32(434))
# Frame 35/447 - 117.1 ms - FPS 8.54
# car 0.72 (np.int32(206), np.int32(405)) (np.int32(256), np.int32(448))
# car 0.65 (np.int32(159), np.int32(400)) (np.int32(207), np.int32(436))
# car 0.61 (np.int32(69), np.int32(421)) (np.int32(96), np.int32(443))
# car 0.54 (np.int32(10), np.int32(420)) (np.int32(49), np.int32(449))
# car 0.49 (np.int32(39), np.int32(420)) (np.int32(62), np.int32(440))
# car 0.32 (np.int32(59), np.int32(417)) (np.int32(74), np.int32(434))
# Frame 36/447 - 113.3 ms - FPS 8.82
# car 0.71 (np.int32(206), np.int32(405)) (np.int32(257), np.int32(450))
# car 0.61 (np.int32(68), np.int32(421)) (np.int32(95), np.int32(443))
# car 0.61 (np.int32(160), np.int32(401)) (np.int32(206), np.int32(437))
# car 0.60 (np.int32(10), np.int32(419)) (np.int32(48), np.int32(449))
# car 0.53 (np.int32(39), np.int32(420)) (np.int32(62), np.int32(441))
# Frame 37/447 - 117.7 ms - FPS 8.49
# car 0.69 (np.int32(206), np.int32(406)) (np.int32(256), np.int32(451))
# car 0.62 (np.int32(160), np.int32(403)) (np.int32(208), np.int32(436))
# car 0.55 (np.int32(39), np.int32(421)) (np.int32(61), np.int32(441))
# car 0.54 (np.int32(69), np.int32(421)) (np.int32(94), np.int32(443))
# car 0.54 (np.int32(9), np.int32(419)) (np.int32(42), np.int32(449))
# car 0.31 (np.int32(117), np.int32(415)) (np.int32(129), np.int32(428))
# Frame 38/447 - 114.9 ms - FPS 8.70
# car 0.68 (np.int32(206), np.int32(403)) (np.int32(257), np.int32(451))
# car 0.62 (np.int32(163), np.int32(402)) (np.int32(206), np.int32(437))
# car 0.57 (np.int32(39), np.int32(421)) (np.int32(61), np.int32(442))
# car 0.56 (np.int32(68), np.int32(422)) (np.int32(94), np.int32(444))
# car 0.49 (np.int32(7), np.int32(419)) (np.int32(41), np.int32(449))
# Frame 39/447 - 114.3 ms - FPS 8.75
# car 0.60 (np.int32(195), np.int32(405)) (np.int32(252), np.int32(455))
# car 0.56 (np.int32(63), np.int32(419)) (np.int32(94), np.int32(447))
# car 0.52 (np.int32(39), np.int32(421)) (np.int32(62), np.int32(441))
# car 0.51 (np.int32(165), np.int32(402)) (np.int32(204), np.int32(436))
# car 0.36 (np.int32(6), np.int32(419)) (np.int32(45), np.int32(449))
# car 0.31 (np.int32(298), np.int32(400)) (np.int32(334), np.int32(427))
# Frame 40/447 - 125.8 ms - FPS 7.95
# car 0.65 (np.int32(194), np.int32(404)) (np.int32(252), np.int32(457))
# car 0.53 (np.int32(166), np.int32(403)) (np.int32(203), np.int32(437))
# car 0.47 (np.int32(38), np.int32(422)) (np.int32(61), np.int32(442))
# car 0.47 (np.int32(62), np.int32(419)) (np.int32(95), np.int32(447))
# car 0.33 (np.int32(6), np.int32(419)) (np.int32(44), np.int32(450))
# Frame 41/447 - 110.0 ms - FPS 9.09
# car 0.68 (np.int32(193), np.int32(406)) (np.int32(251), np.int32(461))
# car 0.57 (np.int32(62), np.int32(420)) (np.int32(94), np.int32(446))
# car 0.53 (np.int32(170), np.int32(405)) (np.int32(202), np.int32(438))
# car 0.46 (np.int32(37), np.int32(422)) (np.int32(62), np.int32(442))
# car 0.37 (np.int32(6), np.int32(420)) (np.int32(46), np.int32(449))
# Frame 42/447 - 118.9 ms - FPS 8.41
# car 0.71 (np.int32(187), np.int32(403)) (np.int32(251), np.int32(461))
# car 0.53 (np.int32(62), np.int32(420)) (np.int32(95), np.int32(446))
# car 0.49 (np.int32(36), np.int32(422)) (np.int32(61), np.int32(443))
# car 0.40 (np.int32(170), np.int32(401)) (np.int32(221), np.int32(439))
# car 0.34 (np.int32(1), np.int32(428)) (np.int32(33), np.int32(459))
# Frame 43/447 - 114.6 ms - FPS 8.73
# car 0.72 (np.int32(188), np.int32(404)) (np.int32(249), np.int32(462))
# car 0.58 (np.int32(62), np.int32(420)) (np.int32(94), np.int32(447))
# car 0.51 (np.int32(171), np.int32(403)) (np.int32(200), np.int32(436))
# car 0.49 (np.int32(36), np.int32(422)) (np.int32(62), np.int32(443))
# car 0.33 (0, np.int32(427)) (np.int32(33), np.int32(459))
# Frame 44/447 - 112.7 ms - FPS 8.87
# car 0.68 (np.int32(182), np.int32(403)) (np.int32(246), np.int32(464))
# car 0.56 (0, np.int32(426)) (np.int32(34), np.int32(457))
# car 0.55 (np.int32(61), np.int32(419)) (np.int32(94), np.int32(447))
# car 0.49 (np.int32(35), np.int32(422)) (np.int32(62), np.int32(443))
# Frame 45/447 - 111.2 ms - FPS 8.99
# car 0.68 (np.int32(183), np.int32(402)) (np.int32(247), np.int32(465))
# car 0.60 (0, np.int32(426)) (np.int32(33), np.int32(458))
# car 0.49 (np.int32(61), np.int32(419)) (np.int32(95), np.int32(447))
# car 0.46 (np.int32(35), np.int32(422)) (np.int32(63), np.int32(444))
# car 0.45 (np.int32(298), np.int32(399)) (np.int32(339), np.int32(427))
# Frame 46/447 - 112.1 ms - FPS 8.92
# car 0.71 (np.int32(185), np.int32(403)) (np.int32(244), np.int32(467))
# car 0.56 (0, np.int32(427)) (np.int32(32), np.int32(460))
# car 0.37 (np.int32(307), np.int32(398)) (np.int32(341), np.int32(426))
# car 0.33 (np.int32(60), np.int32(421)) (np.int32(83), np.int32(440))
# car 0.32 (np.int32(36), np.int32(423)) (np.int32(61), np.int32(442))
# Frame 47/447 - 114.3 ms - FPS 8.75
# car 0.66 (np.int32(181), np.int32(408)) (np.int32(245), np.int32(473))
# car 0.59 (0, np.int32(427)) (np.int32(32), np.int32(458))
# car 0.43 (np.int32(38), np.int32(423)) (np.int32(61), np.int32(443))
# car 0.40 (np.int32(59), np.int32(423)) (np.int32(83), np.int32(442))
# Frame 48/447 - 110.4 ms - FPS 9.05
# car 0.70 (np.int32(178), np.int32(407)) (np.int32(244), np.int32(474))
# car 0.50 (0, np.int32(427)) (np.int32(31), np.int32(460))
# car 0.47 (np.int32(38), np.int32(422)) (np.int32(61), np.int32(444))
# car 0.34 (np.int32(59), np.int32(422)) (np.int32(83), np.int32(442))
# car 0.31 (np.int32(76), np.int32(421)) (np.int32(95), np.int32(437))
# Frame 49/447 - 118.7 ms - FPS 8.42
# car 0.68 (np.int32(174), np.int32(405)) (np.int32(246), np.int32(475))
# car 0.53 (np.int32(48), np.int32(422)) (np.int32(86), np.int32(448))
# car 0.48 (0, np.int32(427)) (np.int32(29), np.int32(459))
# car 0.45 (np.int32(39), np.int32(422)) (np.int32(63), np.int32(444))
# Frame 50/447 - 108.5 ms - FPS 9.22
# car 0.69 (np.int32(167), np.int32(404)) (np.int32(246), np.int32(477))
# car 0.50 (np.int32(48), np.int32(422)) (np.int32(87), np.int32(448))
# car 0.46 (0, np.int32(426)) (np.int32(29), np.int32(460))
# car 0.41 (np.int32(40), np.int32(422)) (np.int32(61), np.int32(443))
# Frame 51/447 - 110.9 ms - FPS 9.02
# car 0.71 (np.int32(164), np.int32(407)) (np.int32(244), np.int32(477))
# car 0.42 (np.int32(48), np.int32(421)) (np.int32(86), np.int32(448))
# car 0.40 (0, np.int32(426)) (np.int32(28), np.int32(459))
# car 0.39 (np.int32(40), np.int32(421)) (np.int32(60), np.int32(442))
# car 0.32 (np.int32(135), np.int32(413)) (np.int32(150), np.int32(430))
# Frame 52/447 - 107.8 ms - FPS 9.28
# car 0.62 (np.int32(161), np.int32(412)) (np.int32(240), np.int32(478))
# car 0.52 (0, np.int32(427)) (np.int32(29), np.int32(459))
# car 0.49 (np.int32(45), np.int32(422)) (np.int32(86), np.int32(448))
# car 0.30 (np.int32(39), np.int32(421)) (np.int32(60), np.int32(441))
# car 0.30 (np.int32(80), np.int32(421)) (np.int32(95), np.int32(438))
# Frame 53/447 - 113.5 ms - FPS 8.81
# car 0.67 (np.int32(158), np.int32(411)) (np.int32(239), np.int32(478))
# car 0.48 (0, np.int32(427)) (np.int32(27), np.int32(459))
# car 0.46 (np.int32(45), np.int32(422)) (np.int32(86), np.int32(448))
# car 0.33 (np.int32(80), np.int32(423)) (np.int32(95), np.int32(439))
# Frame 54/447 - 108.8 ms - FPS 9.19
# car 0.60 (np.int32(153), np.int32(409)) (np.int32(231), np.int32(478))
# car 0.50 (np.int32(1), np.int32(425)) (np.int32(29), np.int32(459))
# car 0.46 (np.int32(44), np.int32(422)) (np.int32(89), np.int32(447))
# car 0.39 (np.int32(219), np.int32(409)) (np.int32(247), np.int32(452))
# car 0.34 (np.int32(80), np.int32(423)) (np.int32(96), np.int32(439))
# car 0.34 (np.int32(311), np.int32(398)) (np.int32(351), np.int32(427))
# car 0.31 (np.int32(58), np.int32(430)) (np.int32(83), np.int32(450))
# Frame 55/447 - 117.3 ms - FPS 8.53
# car 0.55 (np.int32(1), np.int32(425)) (np.int32(30), np.int32(459))
# car 0.51 (np.int32(139), np.int32(408)) (np.int32(248), np.int32(488))
# car 0.42 (np.int32(45), np.int32(422)) (np.int32(88), np.int32(448))
# car 0.41 (np.int32(216), np.int32(411)) (np.int32(247), np.int32(448))
# car 0.38 (np.int32(79), np.int32(424)) (np.int32(96), np.int32(441))
# car 0.35 (np.int32(57), np.int32(430)) (np.int32(84), np.int32(450))
# car 0.32 (np.int32(311), np.int32(399)) (np.int32(348), np.int32(429))
# person 0.32 (np.int32(157), np.int32(405)) (np.int32(170), np.int32(428))
# Frame 56/447 - 110.9 ms - FPS 9.02
# car 0.56 (np.int32(133), np.int32(411)) (np.int32(237), np.int32(490))
# car 0.51 (np.int32(214), np.int32(412)) (np.int32(249), np.int32(448))
# car 0.41 (np.int32(1), np.int32(426)) (np.int32(29), np.int32(458))
# car 0.41 (np.int32(56), np.int32(430)) (np.int32(85), np.int32(450))
# car 0.37 (np.int32(80), np.int32(425)) (np.int32(97), np.int32(441))
# car 0.33 (np.int32(198), np.int32(407)) (np.int32(247), np.int32(453))
# car 0.32 (np.int32(1), np.int32(428)) (np.int32(14), np.int32(455))
# Frame 57/447 - 113.6 ms - FPS 8.80
# car 0.60 (np.int32(131), np.int32(409)) (np.int32(236), np.int32(491))
# car 0.56 (np.int32(215), np.int32(407)) (np.int32(251), np.int32(446))
# car 0.53 (np.int32(42), np.int32(422)) (np.int32(88), np.int32(449))
# car 0.45 (np.int32(81), np.int32(423)) (np.int32(100), np.int32(440))
# car 0.40 (np.int32(253), np.int32(392)) (np.int32(298), np.int32(427))
# car 0.39 (np.int32(200), np.int32(404)) (np.int32(244), np.int32(455))
# car 0.38 (np.int32(1), np.int32(428)) (np.int32(14), np.int32(455))
# car 0.38 (np.int32(1), np.int32(425)) (np.int32(27), np.int32(460))
# car 0.33 (np.int32(312), np.int32(396)) (np.int32(350), np.int32(426))
# Frame 58/447 - 126.1 ms - FPS 7.93
# car 0.66 (np.int32(123), np.int32(409)) (np.int32(236), np.int32(490))
# car 0.59 (np.int32(212), np.int32(408)) (np.int32(251), np.int32(447))
# car 0.49 (np.int32(82), np.int32(424)) (np.int32(99), np.int32(441))
# car 0.46 (np.int32(45), np.int32(422)) (np.int32(87), np.int32(448))
# car 0.45 (np.int32(4), np.int32(425)) (np.int32(45), np.int32(456))
# car 0.41 (np.int32(254), np.int32(391)) (np.int32(298), np.int32(428))
# car 0.37 (np.int32(313), np.int32(397)) (np.int32(349), np.int32(429))
# Frame 59/447 - 112.6 ms - FPS 8.88
# car 0.71 (np.int32(112), np.int32(410)) (np.int32(219), np.int32(496))
# car 0.60 (np.int32(211), np.int32(405)) (np.int32(253), np.int32(447))
# car 0.52 (np.int32(79), np.int32(423)) (np.int32(102), np.int32(442))
# car 0.46 (np.int32(44), np.int32(422)) (np.int32(89), np.int32(448))
# car 0.44 (np.int32(4), np.int32(425)) (np.int32(49), np.int32(455))
# car 0.35 (np.int32(93), np.int32(423)) (np.int32(111), np.int32(437))
# car 0.33 (0, np.int32(430)) (np.int32(13), np.int32(455))
# Frame 60/447 - 109.6 ms - FPS 9.13
# car 0.67 (np.int32(106), np.int32(412)) (np.int32(223), np.int32(501))
# car 0.60 (np.int32(43), np.int32(422)) (np.int32(88), np.int32(449))
# car 0.55 (np.int32(209), np.int32(405)) (np.int32(255), np.int32(447))
# car 0.48 (np.int32(80), np.int32(422)) (np.int32(100), np.int32(441))
# car 0.41 (np.int32(2), np.int32(425)) (np.int32(49), np.int32(456))
# Frame 61/447 - 112.1 ms - FPS 8.92
# car 0.63 (np.int32(98), np.int32(412)) (np.int32(216), np.int32(503))
# car 0.58 (np.int32(208), np.int32(408)) (np.int32(253), np.int32(448))
# car 0.47 (0, np.int32(423)) (np.int32(28), np.int32(459))
# car 0.45 (np.int32(47), np.int32(427)) (np.int32(89), np.int32(453))
# car 0.35 (np.int32(92), np.int32(420)) (np.int32(113), np.int32(435))
# car 0.30 (np.int32(78), np.int32(422)) (np.int32(98), np.int32(439))
# car 0.30 (np.int32(1), np.int32(426)) (np.int32(13), np.int32(457))
# Frame 62/447 - 114.1 ms - FPS 8.77
# car 0.64 (np.int32(187), np.int32(404)) (np.int32(256), np.int32(452))
# car 0.63 (np.int32(86), np.int32(408)) (np.int32(225), np.int32(505))
# car 0.41 (np.int32(43), np.int32(421)) (np.int32(89), np.int32(448))
# car 0.38 (np.int32(1), np.int32(425)) (np.int32(47), np.int32(456))
# Frame 63/447 - 113.3 ms - FPS 8.82
# car 0.66 (np.int32(79), np.int32(410)) (np.int32(209), np.int32(508))
# car 0.59 (np.int32(188), np.int32(402)) (np.int32(257), np.int32(453))
# car 0.44 (np.int32(45), np.int32(420)) (np.int32(88), np.int32(447))
# Frame 64/447 - 135.4 ms - FPS 7.38
# car 0.76 (np.int32(58), np.int32(405)) (np.int32(215), np.int32(515))
# car 0.58 (np.int32(189), np.int32(399)) (np.int32(253), np.int32(452))
# car 0.39 (np.int32(44), np.int32(421)) (np.int32(85), np.int32(444))
# car 0.35 (np.int32(5), np.int32(420)) (np.int32(44), np.int32(450))
# Frame 65/447 - 162.9 ms - FPS 6.14
# car 0.79 (np.int32(42), np.int32(403)) (np.int32(210), np.int32(513))
# car 0.67 (np.int32(205), np.int32(401)) (np.int32(259), np.int32(453))
# car 0.40 (np.int32(275), np.int32(393)) (np.int32(317), np.int32(428))
# car 0.38 (np.int32(331), np.int32(395)) (np.int32(359), np.int32(428))
# car 0.38 (np.int32(44), np.int32(420)) (np.int32(85), np.int32(443))
# car 0.37 (0, np.int32(418)) (np.int32(33), np.int32(449))
# car 0.35 (np.int32(54), np.int32(421)) (np.int32(79), np.int32(438))
# Frame 66/447 - 152.3 ms - FPS 6.56
# car 0.74 (np.int32(36), np.int32(403)) (np.int32(199), np.int32(519))
# car 0.67 (np.int32(205), np.int32(402)) (np.int32(260), np.int32(453))
# Frame 67/447 - 138.8 ms - FPS 7.20
# car 0.76 (np.int32(16), np.int32(402)) (np.int32(201), np.int32(518))
# car 0.72 (np.int32(203), np.int32(401)) (np.int32(260), np.int32(454))
# Frame 68/447 - 139.5 ms - FPS 7.17
# car 0.66 (np.int32(11), np.int32(401)) (np.int32(191), np.int32(521))
# car 0.62 (np.int32(202), np.int32(401)) (np.int32(260), np.int32(454))
# Frame 69/447 - 140.8 ms - FPS 7.10
# car 0.75 (0, np.int32(397)) (np.int32(182), np.int32(530))
# car 0.64 (np.int32(204), np.int32(401)) (np.int32(261), np.int32(456))
# Frame 70/447 - 134.2 ms - FPS 7.45
# car 0.72 (np.int32(201), np.int32(403)) (np.int32(263), np.int32(457))
# car 0.71 (0, np.int32(392)) (np.int32(176), np.int32(536))
# Frame 71/447 - 156.5 ms - FPS 6.39
# car 0.78 (np.int32(2), np.int32(398)) (np.int32(167), np.int32(552))
# car 0.74 (np.int32(202), np.int32(402)) (np.int32(263), np.int32(458))
# Frame 72/447 - 148.5 ms - FPS 6.73
# car 0.68 (np.int32(10), np.int32(402)) (np.int32(159), np.int32(552))
# car 0.59 (np.int32(203), np.int32(402)) (np.int32(263), np.int32(458))
# car 0.34 (0, np.int32(407)) (np.int32(92), np.int32(506))
# Frame 73/447 - 156.9 ms - FPS 6.37
# car 0.71 (np.int32(203), np.int32(401)) (np.int32(264), np.int32(459))
# car 0.71 (0, np.int32(397)) (np.int32(151), np.int32(563))
# Frame 74/447 - 141.6 ms - FPS 7.06
# car 0.76 (np.int32(2), np.int32(400)) (np.int32(132), np.int32(552))
# car 0.62 (np.int32(202), np.int32(401)) (np.int32(264), np.int32(458))
# car 0.31 (np.int32(331), np.int32(394)) (np.int32(359), np.int32(432))
# car 0.31 (np.int32(296), np.int32(391)) (np.int32(333), np.int32(428))
# Frame 75/447 - 149.2 ms - FPS 6.70
# car 0.83 (0, np.int32(394)) (np.int32(125), np.int32(540))
# car 0.66 (np.int32(200), np.int32(403)) (np.int32(264), np.int32(458))
# car 0.33 (np.int32(183), np.int32(399)) (np.int32(205), np.int32(420))
# car 0.32 (np.int32(113), np.int32(415)) (np.int32(131), np.int32(428))
# Frame 76/447 - 142.1 ms - FPS 7.04
# car 0.79 (np.int32(2), np.int32(391)) (np.int32(119), np.int32(535))
# car 0.63 (np.int32(201), np.int32(403)) (np.int32(263), np.int32(458))
# car 0.45 (np.int32(98), np.int32(417)) (np.int32(124), np.int32(432))
# car 0.40 (np.int32(109), np.int32(420)) (np.int32(128), np.int32(432))
# Frame 77/447 - 147.1 ms - FPS 6.80
# car 0.71 (np.int32(2), np.int32(390)) (np.int32(94), np.int32(543))
# car 0.61 (np.int32(200), np.int32(402)) (np.int32(263), np.int32(459))
# car 0.53 (np.int32(89), np.int32(414)) (np.int32(127), np.int32(441))
# car 0.38 (np.int32(110), np.int32(418)) (np.int32(130), np.int32(433))
# car 0.30 (np.int32(96), np.int32(417)) (np.int32(117), np.int32(434))
# Frame 78/447 - 139.3 ms - FPS 7.18
# car 0.76 (np.int32(2), np.int32(397)) (np.int32(85), np.int32(559))
# car 0.63 (np.int32(200), np.int32(400)) (np.int32(263), np.int32(460))
# car 0.45 (np.int32(111), np.int32(419)) (np.int32(130), np.int32(434))
# car 0.37 (np.int32(96), np.int32(417)) (np.int32(114), np.int32(434))
# car 0.33 (np.int32(77), np.int32(415)) (np.int32(95), np.int32(434))
# Frame 79/447 - 145.1 ms - FPS 6.89
# car 0.68 (np.int32(43), np.int32(419)) (np.int32(77), np.int32(449))
# car 0.65 (np.int32(1), np.int32(399)) (np.int32(57), np.int32(531))
# car 0.52 (np.int32(197), np.int32(400)) (np.int32(262), np.int32(459))
# car 0.42 (np.int32(113), np.int32(420)) (np.int32(132), np.int32(435))
# car 0.40 (np.int32(77), np.int32(417)) (np.int32(95), np.int32(438))
# car 0.38 (np.int32(99), np.int32(419)) (np.int32(115), np.int32(437))
# Frame 80/447 - 168.6 ms - FPS 5.93
# car 0.70 (np.int32(42), np.int32(419)) (np.int32(79), np.int32(451))
# car 0.56 (np.int32(193), np.int32(398)) (np.int32(260), np.int32(464))
# car 0.47 (0, np.int32(415)) (np.int32(34), np.int32(496))
# car 0.42 (np.int32(77), np.int32(417)) (np.int32(97), np.int32(438))
# car 0.42 (np.int32(114), np.int32(418)) (np.int32(133), np.int32(433))
# car 0.32 (np.int32(99), np.int32(417)) (np.int32(113), np.int32(433))
# car 0.31 (np.int32(1), np.int32(425)) (np.int32(31), np.int32(541))
# car 0.31 (np.int32(1), np.int32(407)) (np.int32(30), np.int32(455))
# Frame 81/447 - 167.7 ms - FPS 5.96
# car 0.71 (np.int32(191), np.int32(396)) (np.int32(261), np.int32(467))
# car 0.66 (np.int32(41), np.int32(419)) (np.int32(81), np.int32(451))
# car 0.51 (np.int32(77), np.int32(416)) (np.int32(100), np.int32(439))
# car 0.45 (np.int32(114), np.int32(419)) (np.int32(134), np.int32(435))
# car 0.40 (np.int32(257), np.int32(390)) (np.int32(291), np.int32(421))
# car 0.40 (np.int32(3), np.int32(410)) (np.int32(28), np.int32(449))
# car 0.38 (np.int32(1), np.int32(423)) (np.int32(21), np.int32(484))
# car 0.35 (np.int32(308), np.int32(390)) (np.int32(350), np.int32(427))
# car 0.32 (np.int32(97), np.int32(417)) (np.int32(114), np.int32(436))
# Frame 82/447 - 162.7 ms - FPS 6.15
# car 0.62 (np.int32(39), np.int32(418)) (np.int32(82), np.int32(450))
# car 0.56 (np.int32(190), np.int32(396)) (np.int32(259), np.int32(465))
# car 0.54 (np.int32(78), np.int32(416)) (np.int32(100), np.int32(439))
# car 0.53 (np.int32(2), np.int32(412)) (np.int32(30), np.int32(451))
# car 0.44 (np.int32(115), np.int32(419)) (np.int32(135), np.int32(434))
# Frame 83/447 - 172.5 ms - FPS 5.80
# car 0.62 (np.int32(39), np.int32(419)) (np.int32(83), np.int32(450))
# car 0.60 (np.int32(79), np.int32(417)) (np.int32(102), np.int32(437))
# car 0.58 (np.int32(189), np.int32(384)) (np.int32(258), np.int32(471))
# car 0.52 (np.int32(1), np.int32(413)) (np.int32(31), np.int32(449))
# car 0.45 (np.int32(116), np.int32(418)) (np.int32(135), np.int32(435))
# car 0.33 (np.int32(96), np.int32(417)) (np.int32(113), np.int32(435))
# Frame 84/447 - 170.6 ms - FPS 5.86
# car 0.64 (np.int32(39), np.int32(418)) (np.int32(82), np.int32(449))
# car 0.50 (np.int32(114), np.int32(419)) (np.int32(139), np.int32(437))
# car 0.50 (np.int32(8), np.int32(415)) (np.int32(38), np.int32(447))
# car 0.47 (np.int32(183), np.int32(387)) (np.int32(255), np.int32(473))
# car 0.44 (np.int32(79), np.int32(416)) (np.int32(101), np.int32(436))
# car 0.39 (np.int32(3), np.int32(411)) (np.int32(27), np.int32(451))
# car 0.30 (np.int32(85), np.int32(410)) (np.int32(121), np.int32(436))
# Frame 85/447 - 183.1 ms - FPS 5.46
# car 0.65 (np.int32(39), np.int32(417)) (np.int32(83), np.int32(450))
# car 0.56 (np.int32(6), np.int32(414)) (np.int32(38), np.int32(446))
# car 0.50 (np.int32(81), np.int32(416)) (np.int32(101), np.int32(435))
# car 0.50 (np.int32(184), np.int32(394)) (np.int32(250), np.int32(462))
# car 0.42 (np.int32(114), np.int32(418)) (np.int32(137), np.int32(435))
# car 0.32 (np.int32(96), np.int32(417)) (np.int32(115), np.int32(435))
# Frame 86/447 - 175.1 ms - FPS 5.71
# car 0.60 (np.int32(40), np.int32(416)) (np.int32(83), np.int32(450))
# car 0.56 (np.int32(7), np.int32(414)) (np.int32(38), np.int32(445))
# car 0.53 (np.int32(80), np.int32(416)) (np.int32(102), np.int32(436))
# car 0.44 (np.int32(114), np.int32(417)) (np.int32(138), np.int32(435))
# car 0.42 (np.int32(178), np.int32(385)) (np.int32(252), np.int32(473))
# car 0.36 (np.int32(130), np.int32(416)) (np.int32(148), np.int32(431))
# car 0.32 (np.int32(264), np.int32(407)) (np.int32(283), np.int32(424))
# car 0.32 (np.int32(330), np.int32(387)) (np.int32(358), np.int32(435))
# car 0.31 (np.int32(149), np.int32(409)) (np.int32(172), np.int32(423))
# Frame 87/447 - 177.8 ms - FPS 5.62
# car 0.59 (np.int32(168), np.int32(395)) (np.int32(262), np.int32(470))
# car 0.56 (np.int32(28), np.int32(416)) (np.int32(74), np.int32(452))
# car 0.56 (np.int32(6), np.int32(415)) (np.int32(38), np.int32(446))
# car 0.50 (np.int32(81), np.int32(417)) (np.int32(102), np.int32(435))
# car 0.43 (np.int32(129), np.int32(418)) (np.int32(147), np.int32(433))
# car 0.36 (np.int32(116), np.int32(417)) (np.int32(135), np.int32(433))
# car 0.33 (np.int32(95), np.int32(415)) (np.int32(115), np.int32(434))
# Frame 88/447 - 112.9 ms - FPS 8.86
# car 0.60 (np.int32(5), np.int32(414)) (np.int32(38), np.int32(447))
# car 0.59 (np.int32(39), np.int32(415)) (np.int32(85), np.int32(450))
# car 0.50 (np.int32(166), np.int32(398)) (np.int32(259), np.int32(470))
# car 0.46 (np.int32(130), np.int32(418)) (np.int32(148), np.int32(433))
# car 0.44 (np.int32(81), np.int32(417)) (np.int32(102), np.int32(434))
# car 0.39 (np.int32(92), np.int32(413)) (np.int32(111), np.int32(432))
# car 0.34 (np.int32(269), np.int32(410)) (np.int32(285), np.int32(425))
# car 0.32 (np.int32(116), np.int32(416)) (np.int32(132), np.int32(432))
# car 0.30 (np.int32(149), np.int32(409)) (np.int32(170), np.int32(423))
# Frame 89/447 - 117.2 ms - FPS 8.54
# car 0.66 (np.int32(155), np.int32(391)) (np.int32(257), np.int32(478))
# car 0.62 (np.int32(40), np.int32(414)) (np.int32(86), np.int32(450))
# car 0.60 (np.int32(4), np.int32(412)) (np.int32(39), np.int32(444))
# car 0.52 (np.int32(132), np.int32(418)) (np.int32(152), np.int32(433))
# car 0.41 (np.int32(91), np.int32(415)) (np.int32(111), np.int32(433))
# car 0.39 (np.int32(270), np.int32(409)) (np.int32(289), np.int32(427))
# car 0.35 (np.int32(114), np.int32(417)) (np.int32(132), np.int32(434))
# car 0.31 (np.int32(280), np.int32(406)) (np.int32(301), np.int32(424))
# Frame 90/447 - 119.5 ms - FPS 8.37
# car 0.73 (np.int32(148), np.int32(396)) (np.int32(257), np.int32(485))
# car 0.60 (np.int32(42), np.int32(415)) (np.int32(86), np.int32(451))
# car 0.53 (np.int32(87), np.int32(416)) (np.int32(111), np.int32(435))
# car 0.52 (np.int32(28), np.int32(416)) (np.int32(72), np.int32(454))
# car 0.50 (np.int32(5), np.int32(413)) (np.int32(41), np.int32(444))
# car 0.47 (np.int32(134), np.int32(419)) (np.int32(152), np.int32(434))
# car 0.35 (np.int32(116), np.int32(416)) (np.int32(132), np.int32(433))
# car 0.34 (np.int32(281), np.int32(408)) (np.int32(300), np.int32(425))
# Frame 91/447 - 126.8 ms - FPS 7.89
# car 0.69 (np.int32(142), np.int32(398)) (np.int32(258), np.int32(484))
# car 0.56 (np.int32(42), np.int32(416)) (np.int32(87), np.int32(451))
# car 0.54 (np.int32(27), np.int32(415)) (np.int32(72), np.int32(454))
# car 0.50 (np.int32(4), np.int32(412)) (np.int32(43), np.int32(443))
# car 0.47 (np.int32(89), np.int32(416)) (np.int32(112), np.int32(434))
# car 0.43 (np.int32(280), np.int32(405)) (np.int32(303), np.int32(424))
# car 0.40 (np.int32(133), np.int32(417)) (np.int32(153), np.int32(432))
# car 0.34 (np.int32(117), np.int32(416)) (np.int32(132), np.int32(431))
# Frame 92/447 - 117.5 ms - FPS 8.51
# car 0.73 (np.int32(137), np.int32(396)) (np.int32(259), np.int32(486))
# car 0.57 (np.int32(26), np.int32(417)) (np.int32(72), np.int32(453))
# car 0.54 (np.int32(90), np.int32(415)) (np.int32(112), np.int32(434))
# car 0.54 (np.int32(5), np.int32(413)) (np.int32(42), np.int32(443))
# car 0.54 (np.int32(42), np.int32(417)) (np.int32(87), np.int32(451))
# car 0.47 (np.int32(281), np.int32(408)) (np.int32(302), np.int32(427))
# car 0.36 (np.int32(73), np.int32(415)) (np.int32(92), np.int32(437))
# car 0.33 (np.int32(117), np.int32(416)) (np.int32(134), np.int32(432))
# car 0.31 (np.int32(133), np.int32(416)) (np.int32(151), np.int32(431))
# Frame 93/447 - 120.3 ms - FPS 8.31
# car 0.72 (np.int32(132), np.int32(395)) (np.int32(259), np.int32(486))
# car 0.60 (np.int32(281), np.int32(407)) (np.int32(307), np.int32(427))
# car 0.57 (np.int32(41), np.int32(417)) (np.int32(88), np.int32(452))
# car 0.54 (np.int32(91), np.int32(415)) (np.int32(114), np.int32(434))
# car 0.53 (np.int32(5), np.int32(412)) (np.int32(44), np.int32(443))
# car 0.52 (np.int32(26), np.int32(416)) (np.int32(71), np.int32(454))
# car 0.37 (np.int32(72), np.int32(415)) (np.int32(93), np.int32(438))
# Frame 94/447 - 127.0 ms - FPS 7.87
# car 0.70 (np.int32(113), np.int32(391)) (np.int32(255), np.int32(494))
# car 0.64 (np.int32(25), np.int32(417)) (np.int32(74), np.int32(453))
# car 0.56 (np.int32(40), np.int32(415)) (np.int32(88), np.int32(450))
# car 0.51 (np.int32(6), np.int32(413)) (np.int32(44), np.int32(444))
# car 0.46 (np.int32(93), np.int32(415)) (np.int32(118), np.int32(435))
# car 0.44 (np.int32(287), np.int32(409)) (np.int32(308), np.int32(426))
# car 0.42 (np.int32(75), np.int32(415)) (np.int32(95), np.int32(438))
# car 0.39 (np.int32(299), np.int32(410)) (np.int32(321), np.int32(427))
# car 0.31 (np.int32(99), np.int32(407)) (np.int32(138), np.int32(434))
# Frame 95/447 - 119.2 ms - FPS 8.39
# car 0.73 (np.int32(101), np.int32(387)) (np.int32(255), np.int32(497))
# car 0.61 (np.int32(25), np.int32(417)) (np.int32(73), np.int32(453))
# car 0.59 (np.int32(40), np.int32(416)) (np.int32(90), np.int32(451))
# car 0.55 (np.int32(6), np.int32(414)) (np.int32(44), np.int32(445))
# car 0.50 (np.int32(94), np.int32(414)) (np.int32(117), np.int32(432))
# car 0.40 (np.int32(298), np.int32(406)) (np.int32(320), np.int32(425))
# car 0.33 (np.int32(77), np.int32(415)) (np.int32(95), np.int32(436))
# Frame 96/447 - 113.5 ms - FPS 8.81
# car 0.70 (np.int32(92), np.int32(396)) (np.int32(245), np.int32(495))
# car 0.61 (np.int32(39), np.int32(417)) (np.int32(89), np.int32(450))
# car 0.54 (np.int32(5), np.int32(412)) (np.int32(44), np.int32(444))
# car 0.48 (np.int32(297), np.int32(408)) (np.int32(320), np.int32(426))
# car 0.39 (np.int32(95), np.int32(412)) (np.int32(119), np.int32(431))
# car 0.34 (np.int32(78), np.int32(417)) (np.int32(94), np.int32(437))
# Frame 97/447 - 125.3 ms - FPS 7.98
# car 0.80 (np.int32(83), np.int32(383)) (np.int32(247), np.int32(501))
# car 0.62 (np.int32(295), np.int32(406)) (np.int32(322), np.int32(426))
# car 0.56 (np.int32(23), np.int32(416)) (np.int32(75), np.int32(454))
# car 0.53 (np.int32(38), np.int32(414)) (np.int32(92), np.int32(450))
# car 0.50 (np.int32(5), np.int32(411)) (np.int32(47), np.int32(443))
# Frame 98/447 - 117.9 ms - FPS 8.48
# car 0.74 (np.int32(70), np.int32(384)) (np.int32(244), np.int32(504))
# car 0.52 (np.int32(298), np.int32(405)) (np.int32(325), np.int32(426))
# car 0.51 (np.int32(37), np.int32(413)) (np.int32(92), np.int32(450))
# car 0.51 (np.int32(24), np.int32(416)) (np.int32(76), np.int32(453))
# car 0.40 (np.int32(6), np.int32(412)) (np.int32(47), np.int32(444))
# Frame 99/447 - 111.0 ms - FPS 9.01
# car 0.55 (np.int32(303), np.int32(406)) (np.int32(326), np.int32(427))
# car 0.44 (np.int32(43), np.int32(379)) (np.int32(239), np.int32(508))
# car 0.43 (np.int32(21), np.int32(415)) (np.int32(72), np.int32(452))
# car 0.37 (np.int32(8), np.int32(412)) (np.int32(50), np.int32(447))
# Frame 100/447 - 133.1 ms - FPS 7.51
# car 0.69 (np.int32(14), np.int32(381)) (np.int32(234), np.int32(521))
# car 0.53 (np.int32(5), np.int32(412)) (np.int32(45), np.int32(444))
# Frame 101/447 - 114.6 ms - FPS 8.73
# car 0.76 (np.int32(12), np.int32(381)) (np.int32(228), np.int32(529))
# car 0.31 (np.int32(261), np.int32(403)) (np.int32(280), np.int32(419))
# car 0.31 (np.int32(4), np.int32(403)) (np.int32(44), np.int32(444))
# Frame 102/447 - 130.3 ms - FPS 7.68
# car 0.65 (np.int32(17), np.int32(379)) (np.int32(221), np.int32(533))
# car 0.33 (np.int32(247), np.int32(411)) (np.int32(260), np.int32(423))
# Frame 103/447 - 120.7 ms - FPS 8.29
# car 0.68 (np.int32(3), np.int32(375)) (np.int32(211), np.int32(538))
# car 0.30 (np.int32(316), np.int32(409)) (np.int32(337), np.int32(426))
# Frame 104/447 - 120.8 ms - FPS 8.28
# car 0.61 (np.int32(6), np.int32(368)) (np.int32(205), np.int32(559))
# car 0.38 (np.int32(322), np.int32(406)) (np.int32(342), np.int32(426))
# Frame 105/447 - 106.0 ms - FPS 9.44
# car 0.63 (np.int32(8), np.int32(388)) (np.int32(198), np.int32(571))
# car 0.39 (np.int32(324), np.int32(408)) (np.int32(344), np.int32(428))
# Frame 106/447 - 106.9 ms - FPS 9.35
# car 0.69 (np.int32(6), np.int32(381)) (np.int32(189), np.int32(578))
# car 0.31 (np.int32(7), np.int32(409)) (np.int32(348), np.int32(637))
# Frame 107/447 - 112.5 ms - FPS 8.89
# car 0.67 (np.int32(1), np.int32(379)) (np.int32(181), np.int32(583))
# Frame 108/447 - 110.3 ms - FPS 9.07
# car 0.67 (np.int32(3), np.int32(381)) (np.int32(175), np.int32(578))
# car 0.38 (np.int32(167), np.int32(402)) (np.int32(195), np.int32(443))
# car 0.38 (np.int32(172), np.int32(408)) (np.int32(191), np.int32(430))
# car 0.34 (np.int32(212), np.int32(409)) (np.int32(227), np.int32(421))
# Frame 109/447 - 109.8 ms - FPS 9.11
# car 0.66 (0, np.int32(372)) (np.int32(161), np.int32(547))
# car 0.53 (np.int32(159), np.int32(409)) (np.int32(194), np.int32(440))
# Frame 110/447 - 106.3 ms - FPS 9.41
# car 0.67 (np.int32(2), np.int32(370)) (np.int32(143), np.int32(556))
# car 0.60 (np.int32(160), np.int32(410)) (np.int32(196), np.int32(439))
# Frame 111/447 - 115.7 ms - FPS 8.65
# car 0.68 (0, np.int32(369)) (np.int32(127), np.int32(557))
# car 0.55 (np.int32(162), np.int32(409)) (np.int32(199), np.int32(440))
# car 0.49 (np.int32(170), np.int32(417)) (np.int32(198), np.int32(437))
# car 0.34 (np.int32(130), np.int32(415)) (np.int32(147), np.int32(433))
# car 0.31 (np.int32(109), np.int32(404)) (np.int32(147), np.int32(437))
# Frame 112/447 - 117.5 ms - FPS 8.51
# car 0.62 (np.int32(117), np.int32(413)) (np.int32(153), np.int32(440))
# car 0.56 (np.int32(165), np.int32(410)) (np.int32(200), np.int32(439))
# car 0.52 (np.int32(1), np.int32(363)) (np.int32(101), np.int32(565))
# Frame 113/447 - 110.2 ms - FPS 9.07
# car 0.76 (0, np.int32(376)) (np.int32(93), np.int32(581))
# car 0.65 (np.int32(115), np.int32(413)) (np.int32(154), np.int32(440))
# car 0.53 (np.int32(93), np.int32(417)) (np.int32(112), np.int32(445))
# car 0.51 (np.int32(165), np.int32(411)) (np.int32(202), np.int32(441))
# car 0.39 (np.int32(171), np.int32(418)) (np.int32(200), np.int32(436))
# Frame 114/447 - 117.2 ms - FPS 8.53
# car 0.69 (np.int32(117), np.int32(415)) (np.int32(153), np.int32(439))
# car 0.66 (0, np.int32(378)) (np.int32(52), np.int32(526))
# car 0.63 (np.int32(42), np.int32(417)) (np.int32(81), np.int32(454))
# car 0.62 (np.int32(77), np.int32(419)) (np.int32(118), np.int32(445))
# car 0.43 (np.int32(287), np.int32(409)) (np.int32(302), np.int32(423))
# car 0.42 (np.int32(168), np.int32(410)) (np.int32(205), np.int32(440))
# car 0.33 (np.int32(231), np.int32(407)) (np.int32(248), np.int32(421))
# car 0.32 (np.int32(172), np.int32(414)) (np.int32(197), np.int32(431))
# Frame 115/447 - 116.8 ms - FPS 8.56
# car 0.67 (np.int32(76), np.int32(419)) (np.int32(119), np.int32(444))
# car 0.66 (np.int32(119), np.int32(414)) (np.int32(155), np.int32(438))
# car 0.61 (np.int32(18), np.int32(413)) (np.int32(76), np.int32(459))
# car 0.50 (np.int32(175), np.int32(412)) (np.int32(210), np.int32(441))
# car 0.45 (np.int32(1), np.int32(397)) (np.int32(25), np.int32(511))
# car 0.44 (np.int32(288), np.int32(412)) (np.int32(304), np.int32(425))
# car 0.39 (np.int32(182), np.int32(416)) (np.int32(207), np.int32(434))
# Frame 116/447 - 114.3 ms - FPS 8.75
# car 0.64 (np.int32(119), np.int32(414)) (np.int32(159), np.int32(437))
# car 0.58 (np.int32(74), np.int32(419)) (np.int32(119), np.int32(444))
# car 0.55 (np.int32(7), np.int32(413)) (np.int32(77), np.int32(458))
# car 0.51 (np.int32(174), np.int32(410)) (np.int32(212), np.int32(439))
# car 0.35 (np.int32(182), np.int32(417)) (np.int32(208), np.int32(434))
# Frame 117/447 - 111.4 ms - FPS 8.98
# car 0.63 (np.int32(75), np.int32(419)) (np.int32(119), np.int32(445))
# car 0.56 (np.int32(124), np.int32(414)) (np.int32(160), np.int32(439))
# car 0.49 (np.int32(11), np.int32(413)) (np.int32(75), np.int32(458))
# car 0.47 (np.int32(179), np.int32(417)) (np.int32(210), np.int32(435))
# car 0.47 (np.int32(175), np.int32(411)) (np.int32(214), np.int32(440))
# car 0.35 (np.int32(228), np.int32(406)) (np.int32(245), np.int32(420))
# Frame 118/447 - 109.6 ms - FPS 9.13
# car 0.65 (np.int32(69), np.int32(421)) (np.int32(114), np.int32(447))
# car 0.62 (np.int32(125), np.int32(415)) (np.int32(161), np.int32(439))
# car 0.57 (np.int32(174), np.int32(411)) (np.int32(213), np.int32(438))
# car 0.45 (np.int32(15), np.int32(414)) (np.int32(74), np.int32(457))
# car 0.31 (np.int32(299), np.int32(408)) (np.int32(315), np.int32(422))
# Frame 119/447 - 110.5 ms - FPS 9.05
# car 0.68 (np.int32(68), np.int32(422)) (np.int32(117), np.int32(447))
# car 0.61 (np.int32(126), np.int32(415)) (np.int32(162), np.int32(439))
# car 0.61 (np.int32(179), np.int32(418)) (np.int32(215), np.int32(437))
# car 0.52 (np.int32(3), np.int32(416)) (np.int32(64), np.int32(462))
# Frame 120/447 - 120.7 ms - FPS 8.29
# car 0.70 (np.int32(66), np.int32(423)) (np.int32(117), np.int32(447))
# car 0.67 (np.int32(126), np.int32(416)) (np.int32(162), np.int32(440))
# car 0.59 (np.int32(1), np.int32(416)) (np.int32(66), np.int32(462))
# car 0.57 (np.int32(182), np.int32(416)) (np.int32(214), np.int32(434))
# car 0.31 (np.int32(231), np.int32(407)) (np.int32(247), np.int32(421))
# Frame 121/447 - 109.6 ms - FPS 9.13
# car 0.66 (np.int32(127), np.int32(416)) (np.int32(163), np.int32(439))
# car 0.65 (np.int32(64), np.int32(421)) (np.int32(119), np.int32(446))
# car 0.61 (np.int32(2), np.int32(416)) (np.int32(66), np.int32(462))
# car 0.52 (np.int32(184), np.int32(417)) (np.int32(215), np.int32(436))
# Frame 122/447 - 112.2 ms - FPS 8.92
# car 0.70 (np.int32(128), np.int32(417)) (np.int32(165), np.int32(441))
# car 0.66 (np.int32(62), np.int32(421)) (np.int32(118), np.int32(446))
# car 0.62 (np.int32(1), np.int32(417)) (np.int32(64), np.int32(463))
# car 0.48 (np.int32(185), np.int32(416)) (np.int32(216), np.int32(438))
# Frame 123/447 - 111.4 ms - FPS 8.98
# car 0.71 (np.int32(1), np.int32(416)) (np.int32(65), np.int32(464))
# car 0.66 (np.int32(127), np.int32(416)) (np.int32(166), np.int32(440))
# car 0.65 (np.int32(62), np.int32(422)) (np.int32(114), np.int32(448))
# car 0.49 (np.int32(186), np.int32(418)) (np.int32(216), np.int32(438))
# car 0.37 (np.int32(264), np.int32(406)) (np.int32(282), np.int32(419))
# Frame 124/447 - 110.1 ms - FPS 9.08
# car 0.70 (0, np.int32(416)) (np.int32(58), np.int32(465))
# car 0.61 (np.int32(65), np.int32(422)) (np.int32(111), np.int32(448))
# car 0.57 (np.int32(131), np.int32(415)) (np.int32(168), np.int32(440))
# car 0.44 (np.int32(79), np.int32(418)) (np.int32(122), np.int32(445))
# car 0.43 (np.int32(319), np.int32(408)) (np.int32(333), np.int32(424))
# car 0.41 (np.int32(191), np.int32(416)) (np.int32(218), np.int32(436))
# car 0.41 (np.int32(266), np.int32(408)) (np.int32(286), np.int32(421))
# car 0.39 (np.int32(212), np.int32(415)) (np.int32(235), np.int32(434))
# car 0.33 (np.int32(248), np.int32(407)) (np.int32(263), np.int32(420))
# car 0.32 (np.int32(116), np.int32(419)) (np.int32(130), np.int32(438))
# Frame 125/447 - 112.0 ms - FPS 8.93
# car 0.73 (np.int32(1), np.int32(414)) (np.int32(58), np.int32(466))
# car 0.61 (np.int32(64), np.int32(422)) (np.int32(113), np.int32(448))
# car 0.59 (np.int32(129), np.int32(415)) (np.int32(170), np.int32(440))
# car 0.48 (np.int32(190), np.int32(418)) (np.int32(220), np.int32(439))
# car 0.44 (np.int32(212), np.int32(417)) (np.int32(236), np.int32(436))
# car 0.34 (np.int32(250), np.int32(406)) (np.int32(265), np.int32(419))
# car 0.34 (np.int32(268), np.int32(407)) (np.int32(284), np.int32(420))
# Frame 126/447 - 108.1 ms - FPS 9.25
# car 0.77 (0, np.int32(416)) (np.int32(56), np.int32(467))
# car 0.61 (np.int32(63), np.int32(421)) (np.int32(114), np.int32(450))
# car 0.54 (np.int32(130), np.int32(415)) (np.int32(169), np.int32(439))
# car 0.46 (np.int32(190), np.int32(417)) (np.int32(221), np.int32(439))
# car 0.32 (np.int32(213), np.int32(417)) (np.int32(236), np.int32(435))
# ...
# car 0.41 (np.int32(120), np.int32(526)) (np.int32(133), np.int32(538))
# Frame 420/447 - 114.2 ms - FPS 8.75
# car 0.79 (np.int32(215), np.int32(528)) (np.int32(265), np.int32(573))
# car 0.69 (np.int32(75), np.int32(521)) (np.int32(107), np.int32(551))
# car 0.49 (np.int32(335), np.int32(530)) (360, np.int32(575))
# car 0.42 (np.int32(120), np.int32(526)) (np.int32(133), np.int32(538))
# traffic light 0.41 (np.int32(221), np.int32(365)) (np.int32(230), np.int32(384))
# car 0.32 (np.int32(207), np.int32(522)) (np.int32(222), np.int32(538))
# Frame 421/447 - 111.5 ms - FPS 8.97
# car 0.75 (np.int32(217), np.int32(524)) (np.int32(270), np.int32(570))
# car 0.74 (np.int32(71), np.int32(522)) (np.int32(105), np.int32(551))
# traffic light 0.59 (np.int32(222), np.int32(354)) (np.int32(234), np.int32(380))
# car 0.42 (np.int32(120), np.int32(526)) (np.int32(134), np.int32(538))
# car 0.33 (np.int32(18), np.int32(521)) (np.int32(43), np.int32(545))
# car 0.31 (np.int32(174), np.int32(518)) (np.int32(195), np.int32(543))
# Frame 422/447 - 118.8 ms - FPS 8.42
# car 0.76 (np.int32(68), np.int32(521)) (np.int32(102), np.int32(553))
# car 0.69 (np.int32(222), np.int32(525)) (np.int32(275), np.int32(573))
# traffic light 0.50 (np.int32(223), np.int32(348)) (np.int32(236), np.int32(368))
# car 0.48 (np.int32(120), np.int32(524)) (np.int32(135), np.int32(538))
# car 0.41 (np.int32(101), np.int32(525)) (np.int32(116), np.int32(540))
# car 0.31 (np.int32(210), np.int32(524)) (np.int32(224), np.int32(542))
# Frame 423/447 - 110.6 ms - FPS 9.04
# car 0.73 (np.int32(66), np.int32(520)) (np.int32(102), np.int32(554))
# car 0.71 (np.int32(222), np.int32(525)) (np.int32(276), np.int32(573))
# traffic light 0.50 (np.int32(224), np.int32(342)) (np.int32(237), np.int32(362))
# car 0.45 (np.int32(120), np.int32(524)) (np.int32(134), np.int32(538))
# car 0.38 (np.int32(101), np.int32(525)) (np.int32(116), np.int32(540))
# car 0.36 (np.int32(212), np.int32(528)) (np.int32(226), np.int32(553))
# car 0.31 (np.int32(210), np.int32(525)) (np.int32(224), np.int32(542))
# Frame 424/447 - 113.6 ms - FPS 8.80
# car 0.72 (np.int32(226), np.int32(525)) (np.int32(280), np.int32(574))
# car 0.69 (np.int32(62), np.int32(520)) (np.int32(98), np.int32(552))
# car 0.59 (np.int32(213), np.int32(528)) (np.int32(228), np.int32(553))
# traffic light 0.54 (np.int32(226), np.int32(331)) (np.int32(242), np.int32(354))
# car 0.48 (np.int32(120), np.int32(524)) (np.int32(135), np.int32(537))
# car 0.43 (np.int32(101), np.int32(526)) (np.int32(116), np.int32(540))
# Frame 425/447 - 119.0 ms - FPS 8.40
# car 0.76 (np.int32(229), np.int32(528)) (np.int32(282), np.int32(576))
# traffic light 0.62 (np.int32(228), np.int32(317)) (np.int32(245), np.int32(349))
# car 0.61 (np.int32(60), np.int32(519)) (np.int32(96), np.int32(552))
# car 0.61 (np.int32(214), np.int32(528)) (np.int32(232), np.int32(553))
# car 0.45 (np.int32(121), np.int32(525)) (np.int32(134), np.int32(537))
# car 0.34 (np.int32(7), np.int32(518)) (np.int32(43), np.int32(546))
# car 0.34 (np.int32(101), np.int32(528)) (np.int32(115), np.int32(539))
# Frame 426/447 - 126.0 ms - FPS 7.93
# car 0.75 (np.int32(232), np.int32(529)) (np.int32(287), np.int32(575))
# car 0.72 (np.int32(49), np.int32(520)) (np.int32(95), np.int32(555))
# car 0.64 (np.int32(213), np.int32(528)) (np.int32(234), np.int32(553))
# car 0.51 (np.int32(121), np.int32(523)) (np.int32(135), np.int32(537))
# car 0.49 (np.int32(95), np.int32(526)) (np.int32(113), np.int32(541))
# traffic light 0.49 (np.int32(235), np.int32(310)) (np.int32(249), np.int32(336))
# Frame 427/447 - 108.5 ms - FPS 9.22
# car 0.75 (np.int32(44), np.int32(518)) (np.int32(91), np.int32(557))
# car 0.67 (np.int32(235), np.int32(531)) (np.int32(290), np.int32(575))
# car 0.54 (np.int32(213), np.int32(529)) (np.int32(234), np.int32(553))
# car 0.52 (np.int32(93), np.int32(527)) (np.int32(111), np.int32(540))
# car 0.42 (np.int32(219), np.int32(531)) (np.int32(241), np.int32(554))
# car 0.38 (np.int32(120), np.int32(523)) (np.int32(132), np.int32(535))
# traffic light 0.33 (np.int32(233), np.int32(295)) (np.int32(253), np.int32(321))
# Frame 428/447 - 115.8 ms - FPS 8.63
# car 0.69 (np.int32(42), np.int32(518)) (np.int32(89), np.int32(557))
# car 0.63 (np.int32(242), np.int32(529)) (np.int32(295), np.int32(577))
# car 0.57 (np.int32(217), np.int32(529)) (np.int32(243), np.int32(555))
# car 0.56 (np.int32(94), np.int32(527)) (np.int32(110), np.int32(540))
# traffic light 0.48 (np.int32(237), np.int32(282)) (np.int32(264), np.int32(317))
# car 0.43 (np.int32(120), np.int32(524)) (np.int32(132), np.int32(536))
# traffic light 0.38 (np.int32(236), np.int32(285)) (np.int32(253), np.int32(315))
# car 0.35 (np.int32(213), np.int32(529)) (np.int32(231), np.int32(553))
# traffic light 0.32 (np.int32(240), np.int32(297)) (np.int32(258), np.int32(315))
# car 0.31 (np.int32(292), np.int32(531)) (np.int32(322), np.int32(555))
# Frame 429/447 - 115.2 ms - FPS 8.68
# car 0.69 (np.int32(240), np.int32(527)) (np.int32(301), np.int32(577))
# car 0.63 (np.int32(41), np.int32(519)) (np.int32(85), np.int32(554))
# traffic light 0.54 (np.int32(240), np.int32(276)) (np.int32(261), np.int32(303))
# car 0.52 (np.int32(217), np.int32(529)) (np.int32(243), np.int32(555))
# car 0.52 (np.int32(94), np.int32(527)) (np.int32(110), np.int32(539))
# car 0.50 (np.int32(28), np.int32(525)) (np.int32(78), np.int32(561))
# car 0.41 (np.int32(121), np.int32(524)) (np.int32(133), np.int32(537))
# car 0.38 (np.int32(6), np.int32(508)) (np.int32(39), np.int32(541))
# car 0.35 (np.int32(78), np.int32(525)) (np.int32(94), np.int32(540))
# Frame 430/447 - 114.0 ms - FPS 8.77
# car 0.71 (np.int32(240), np.int32(528)) (np.int32(303), np.int32(577))
# car 0.63 (np.int32(25), np.int32(523)) (np.int32(79), np.int32(562))
# car 0.62 (np.int32(40), np.int32(520)) (np.int32(82), np.int32(554))
# car 0.54 (np.int32(217), np.int32(529)) (np.int32(245), np.int32(554))
# traffic light 0.51 (np.int32(242), np.int32(255)) (np.int32(267), np.int32(295))
# car 0.49 (np.int32(95), np.int32(527)) (np.int32(109), np.int32(539))
# car 0.46 (np.int32(79), np.int32(526)) (np.int32(95), np.int32(541))
# car 0.44 (np.int32(120), np.int32(524)) (np.int32(132), np.int32(537))
# traffic light 0.43 (np.int32(247), np.int32(264)) (np.int32(264), np.int32(292))
# car 0.35 (np.int32(6), np.int32(510)) (np.int32(39), np.int32(542))
# Frame 431/447 - 114.7 ms - FPS 8.72
# car 0.71 (np.int32(246), np.int32(525)) (np.int32(306), np.int32(576))
# car 0.67 (np.int32(18), np.int32(520)) (np.int32(76), np.int32(564))
# car 0.63 (np.int32(214), np.int32(527)) (np.int32(245), np.int32(559))
# car 0.50 (np.int32(96), np.int32(527)) (np.int32(111), np.int32(539))
# traffic light 0.49 (np.int32(246), np.int32(237)) (np.int32(271), np.int32(279))
# car 0.46 (np.int32(79), np.int32(528)) (np.int32(96), np.int32(542))
# car 0.45 (np.int32(120), np.int32(525)) (np.int32(132), np.int32(536))
# Frame 432/447 - 112.5 ms - FPS 8.89
# car 0.71 (np.int32(247), np.int32(525)) (np.int32(312), np.int32(576))
# car 0.69 (np.int32(7), np.int32(518)) (np.int32(73), np.int32(565))
# car 0.66 (np.int32(214), np.int32(528)) (np.int32(246), np.int32(560))
# traffic light 0.56 (np.int32(255), np.int32(207)) (np.int32(282), np.int32(253))
# car 0.51 (np.int32(77), np.int32(527)) (np.int32(96), np.int32(543))
# car 0.48 (np.int32(119), np.int32(523)) (np.int32(132), np.int32(537))
# car 0.47 (np.int32(97), np.int32(526)) (np.int32(111), np.int32(539))
# car 0.33 (np.int32(244), np.int32(524)) (np.int32(259), np.int32(540))
# Frame 433/447 - 108.7 ms - FPS 9.20
# car 0.73 (np.int32(214), np.int32(526)) (np.int32(245), np.int32(559))
# car 0.71 (np.int32(248), np.int32(522)) (np.int32(314), np.int32(577))
# car 0.70 (np.int32(6), np.int32(517)) (np.int32(73), np.int32(566))
# traffic light 0.67 (np.int32(256), np.int32(197)) (np.int32(285), np.int32(238))
# car 0.53 (np.int32(74), np.int32(527)) (np.int32(97), np.int32(543))
# car 0.47 (np.int32(118), np.int32(522)) (np.int32(131), np.int32(536))
# car 0.46 (np.int32(242), np.int32(524)) (np.int32(260), np.int32(540))
# car 0.41 (np.int32(97), np.int32(525)) (np.int32(110), np.int32(538))
# Frame 434/447 - 119.0 ms - FPS 8.40
# car 0.75 (np.int32(214), np.int32(527)) (np.int32(245), np.int32(558))
# car 0.71 (np.int32(255), np.int32(522)) (np.int32(322), np.int32(576))
# car 0.65 (np.int32(1), np.int32(517)) (np.int32(65), np.int32(568))
# car 0.55 (np.int32(76), np.int32(527)) (np.int32(97), np.int32(544))
# car 0.54 (np.int32(242), np.int32(524)) (np.int32(260), np.int32(544))
# car 0.51 (np.int32(117), np.int32(523)) (np.int32(130), np.int32(537))
# car 0.45 (np.int32(96), np.int32(526)) (np.int32(110), np.int32(539))
# traffic light 0.40 (np.int32(264), np.int32(159)) (np.int32(292), np.int32(212))
# Frame 435/447 - 156.6 ms - FPS 6.38
# car 0.75 (np.int32(214), np.int32(526)) (np.int32(244), np.int32(558))
# car 0.70 (np.int32(257), np.int32(522)) (np.int32(329), np.int32(578))
# car 0.70 (np.int32(1), np.int32(519)) (np.int32(57), np.int32(567))
# car 0.55 (np.int32(75), np.int32(527)) (np.int32(96), np.int32(543))
# car 0.53 (np.int32(243), np.int32(524)) (np.int32(263), np.int32(544))
# car 0.47 (np.int32(96), np.int32(526)) (np.int32(110), np.int32(539))
# car 0.46 (np.int32(116), np.int32(523)) (np.int32(129), np.int32(536))
# car 0.33 (np.int32(63), np.int32(527)) (np.int32(79), np.int32(541))
# Frame 436/447 - 116.2 ms - FPS 8.61
# car 0.79 (np.int32(214), np.int32(527)) (np.int32(244), np.int32(557))
# car 0.74 (np.int32(261), np.int32(523)) (np.int32(334), np.int32(580))
# car 0.69 (0, np.int32(518)) (np.int32(51), np.int32(567))
# car 0.52 (np.int32(73), np.int32(526)) (np.int32(97), np.int32(544))
# car 0.51 (np.int32(115), np.int32(523)) (np.int32(128), np.int32(537))
# car 0.45 (np.int32(246), np.int32(525)) (np.int32(265), np.int32(544))
# car 0.44 (np.int32(62), np.int32(524)) (np.int32(83), np.int32(542))
# car 0.42 (np.int32(98), np.int32(525)) (np.int32(112), np.int32(539))
# traffic light 0.31 (np.int32(282), np.int32(67)) (np.int32(331), np.int32(122))
# Frame 437/447 - 116.0 ms - FPS 8.62
# car 0.75 (np.int32(214), np.int32(527)) (np.int32(244), np.int32(557))
# car 0.69 (0, np.int32(519)) (np.int32(45), np.int32(571))
# car 0.58 (np.int32(271), np.int32(521)) (np.int32(343), np.int32(580))
# car 0.53 (np.int32(114), np.int32(523)) (np.int32(128), np.int32(537))
# car 0.52 (np.int32(60), np.int32(525)) (np.int32(83), np.int32(543))
# car 0.51 (np.int32(75), np.int32(526)) (np.int32(97), np.int32(544))
# car 0.47 (np.int32(295), np.int32(1)) (np.int32(355), np.int32(77))
# car 0.41 (np.int32(247), np.int32(526)) (np.int32(266), np.int32(544))
# car 0.38 (np.int32(97), np.int32(525)) (np.int32(111), np.int32(539))
# car 0.30 (np.int32(174), np.int32(518)) (np.int32(196), np.int32(541))
# Frame 438/447 - 133.5 ms - FPS 7.49
# car 0.75 (np.int32(214), np.int32(526)) (np.int32(244), np.int32(557))
# car 0.71 (np.int32(1), np.int32(518)) (np.int32(39), np.int32(571))
# car 0.64 (np.int32(267), np.int32(523)) (np.int32(346), np.int32(582))
# car 0.54 (np.int32(112), np.int32(523)) (np.int32(128), np.int32(538))
# car 0.47 (np.int32(61), np.int32(524)) (np.int32(82), np.int32(543))
# car 0.46 (np.int32(75), np.int32(525)) (np.int32(96), np.int32(543))
# car 0.38 (np.int32(98), np.int32(525)) (np.int32(112), np.int32(539))
# car 0.35 (np.int32(248), np.int32(525)) (np.int32(267), np.int32(543))
# car 0.31 (np.int32(174), np.int32(518)) (np.int32(196), np.int32(541))
# Frame 439/447 - 115.4 ms - FPS 8.66
# car 0.75 (np.int32(268), np.int32(523)) (np.int32(345), np.int32(586))
# car 0.74 (0, np.int32(517)) (np.int32(29), np.int32(573))
# car 0.72 (np.int32(215), np.int32(526)) (np.int32(244), np.int32(557))
# car 0.46 (np.int32(76), np.int32(526)) (np.int32(97), np.int32(544))
# car 0.44 (np.int32(114), np.int32(522)) (np.int32(127), np.int32(538))
# car 0.44 (np.int32(61), np.int32(524)) (np.int32(81), np.int32(542))
# car 0.40 (np.int32(262), np.int32(523)) (np.int32(282), np.int32(544))
# car 0.32 (np.int32(248), np.int32(525)) (np.int32(265), np.int32(540))
# car 0.32 (np.int32(99), np.int32(524)) (np.int32(112), np.int32(539))
# Frame 440/447 - 120.4 ms - FPS 8.31
# car 0.76 (np.int32(270), np.int32(524)) (np.int32(347), np.int32(588))
# car 0.71 (np.int32(215), np.int32(526)) (np.int32(244), np.int32(557))
# car 0.69 (0, np.int32(518)) (np.int32(22), np.int32(577))
# car 0.49 (np.int32(60), np.int32(524)) (np.int32(81), np.int32(542))
# car 0.43 (np.int32(262), np.int32(523)) (np.int32(282), np.int32(544))
# car 0.42 (np.int32(77), np.int32(525)) (np.int32(96), np.int32(544))
# car 0.37 (np.int32(100), np.int32(524)) (np.int32(113), np.int32(539))
# car 0.36 (np.int32(115), np.int32(521)) (np.int32(127), np.int32(536))
# car 0.34 (np.int32(247), np.int32(524)) (np.int32(266), np.int32(541))
# Frame 441/447 - 116.6 ms - FPS 8.58
# car 0.77 (np.int32(277), np.int32(523)) (np.int32(351), np.int32(589))
# car 0.69 (np.int32(214), np.int32(526)) (np.int32(244), np.int32(557))
# car 0.50 (np.int32(98), np.int32(525)) (np.int32(114), np.int32(542))
# car 0.49 (np.int32(59), np.int32(525)) (np.int32(82), np.int32(542))
# car 0.48 (0, np.int32(509)) (np.int32(12), np.int32(602))
# car 0.41 (np.int32(76), np.int32(525)) (np.int32(95), np.int32(543))
# car 0.32 (np.int32(117), np.int32(523)) (np.int32(128), np.int32(537))
# car 0.30 (np.int32(174), np.int32(518)) (np.int32(196), np.int32(541))
# Frame 442/447 - 116.8 ms - FPS 8.56
# car 0.73 (np.int32(279), np.int32(522)) (np.int32(354), np.int32(588))
# car 0.68 (np.int32(214), np.int32(528)) (np.int32(244), np.int32(558))
# car 0.62 (np.int32(58), np.int32(525)) (np.int32(81), np.int32(544))
# car 0.48 (np.int32(98), np.int32(526)) (np.int32(112), np.int32(541))
# car 0.42 (np.int32(79), np.int32(526)) (np.int32(96), np.int32(543))
# car 0.37 (np.int32(116), np.int32(522)) (np.int32(127), np.int32(537))
# car 0.31 (np.int32(263), np.int32(526)) (np.int32(283), np.int32(542))
# Frame 443/447 - 126.8 ms - FPS 7.89
# car 0.65 (np.int32(214), np.int32(528)) (np.int32(245), np.int32(557))
# car 0.63 (np.int32(58), np.int32(526)) (np.int32(82), np.int32(544))
# car 0.63 (np.int32(283), np.int32(519)) (np.int32(352), np.int32(587))
# car 0.45 (np.int32(98), np.int32(526)) (np.int32(112), np.int32(541))
# car 0.39 (np.int32(79), np.int32(526)) (np.int32(96), np.int32(542))
# car 0.35 (np.int32(117), np.int32(523)) (np.int32(127), np.int32(537))
# car 0.33 (np.int32(248), np.int32(525)) (np.int32(267), np.int32(541))
# Frame 444/447 - 117.1 ms - FPS 8.54
# car 0.69 (np.int32(287), np.int32(521)) (360, np.int32(593))
# car 0.65 (np.int32(56), np.int32(526)) (np.int32(80), np.int32(544))
# car 0.63 (np.int32(214), np.int32(528)) (np.int32(246), np.int32(557))
# car 0.52 (np.int32(99), np.int32(527)) (np.int32(114), np.int32(542))
# car 0.42 (np.int32(79), np.int32(526)) (np.int32(96), np.int32(542))
# car 0.35 (np.int32(117), np.int32(523)) (np.int32(128), np.int32(537))
# car 0.31 (np.int32(174), np.int32(520)) (np.int32(196), np.int32(541))
# Frame 445/447 - 114.4 ms - FPS 8.74
# car 0.69 (np.int32(290), np.int32(520)) (360, np.int32(595))
# car 0.63 (np.int32(214), np.int32(528)) (np.int32(247), np.int32(556))
# car 0.60 (np.int32(56), np.int32(526)) (np.int32(79), np.int32(544))
# car 0.44 (np.int32(98), np.int32(525)) (np.int32(114), np.int32(541))
# car 0.41 (np.int32(78), np.int32(526)) (np.int32(97), np.int32(544))
# car 0.40 (np.int32(117), np.int32(523)) (np.int32(129), np.int32(538))
# car 0.31 (np.int32(175), np.int32(519)) (np.int32(196), np.int32(541))
# Frame 446/447 - 117.7 ms - FPS 8.50
# car 0.71 (np.int32(296), np.int32(519)) (360, np.int32(596))
# car 0.62 (np.int32(214), np.int32(528)) (np.int32(248), np.int32(555))
# car 0.62 (np.int32(54), np.int32(527)) (np.int32(77), np.int32(544))
# car 0.48 (np.int32(98), np.int32(526)) (np.int32(113), np.int32(542))
# car 0.39 (np.int32(80), np.int32(527)) (np.int32(96), np.int32(543))
# car 0.33 (np.int32(253), np.int32(522)) (np.int32(294), np.int32(548))
# car 0.33 (np.int32(117), np.int32(522)) (np.int32(128), np.int32(537))
# car 0.32 (np.int32(262), np.int32(525)) (np.int32(289), np.int32(544))
# Frame 447/447 - 115.3 ms - FPS 8.68
# ✅ Saved output video to: /content/drive/MyDrive/Colab Notebooks/DPL/Lab/Lab1/Lab_3_full_v1/out/Test_video.mp4

# %% [markdown]
# <a name='4'></a>
# ## 4 - Summary for YOLO
#
# - Input image (608, 608, 3)
# - The input image goes through a CNN, resulting in a (19,19,5,85) dimensional output.
# - After flattening the last two dimensions, the output is a volume of shape (19, 19, 425):
#     - Each cell in a 19x19 grid over the input image gives 425 numbers.
#     - 425 = 5 x 85 because each cell contains predictions for 5 boxes, corresponding to 5 anchor boxes, as seen in lecture.
#     - 85 = 5 + 80 where 5 is because $(p_c, b_x, b_y, b_h, b_w)$ has 5 numbers, and 80 is the number of classes we'd like to detect
# - You then select only few boxes based on:
#     - Score-thresholding: throw away boxes that have detected a class with a score less than the threshold
#     - Non-max suppression: Compute the Intersection over Union and avoid selecting overlapping boxes
# - This gives you YOLO's final output.

# %% [markdown]
# <font color='blue'>
#
# **What you should remember**:
#
# - YOLO is a state-of-the-art object detection model that is fast and accurate
# - It runs an input image through a CNN, which outputs a 19x19x5x85 dimensional volume.
# - The encoding can be seen as a grid where each of the 19x19 cells contains information about 5 boxes.
# - You filter through all the boxes using non-max suppression. Specifically:
#     - Score thresholding on the probability of detecting a class to keep only accurate (high probability) boxes
#     - Intersection over Union (IoU) thresholding to eliminate overlapping boxes
# - Because training a YOLO model from randomly initialized weights is non-trivial and requires a large dataset as well as lot of computation, previously trained model parameters were used in this exercise. If you wish, you can also try fine-tuning the YOLO model with your own dataset, though this would be a fairly non-trivial exercise.

# %% [markdown]
# **Congratulations!** You've come to the end of this assignment.
#
# Here's a quick recap of all you've accomplished.
#
# You've:
#
# - Detected objects in a car detection dataset
# - Implemented non-max suppression to achieve better accuracy
# - Implemented intersection over union as a function of NMS
# - Created usable bounding box tensors from the model's predictions
#
# Amazing work! If you'd like to know more about the origins of these ideas, spend some time on the papers referenced below.

# %% [markdown]
# <a name='5'></a>
# ## 5 - References
#
# The ideas presented in this notebook came primarily from the two YOLO papers. The implementation here also took significant inspiration and used many components from Allan Zelener's GitHub repository. The pre-trained weights used in this exercise came from the official YOLO website.
# - Joseph Redmon, Santosh Divvala, Ross Girshick, Ali Farhadi - [You Only Look Once: Unified, Real-Time Object Detection](https://arxiv.org/abs/1506.02640) (2015)
# - Joseph Redmon, Ali Farhadi - [YOLO9000: Better, Faster, Stronger](https://arxiv.org/abs/1612.08242) (2016)
# - Allan Zelener - [YAD2K: Yet Another Darknet 2 Keras](https://github.com/allanzelener/YAD2K)
# - The official YOLO website (https://pjreddie.com/darknet/yolo/)
#
# ### Car detection dataset
#
# <a rel="license" href="http://creativecommons.org/licenses/by/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">The Drive.ai Sample Dataset</span> (provided by drive.ai) is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by/4.0/">Creative Commons Attribution 4.0 International License</a>. Thanks to Brody Huval, Chih Hu and Rahul Patel for  providing this data.
